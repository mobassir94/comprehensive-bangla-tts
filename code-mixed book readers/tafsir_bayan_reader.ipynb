# %% [markdown]
# <a href="https://colab.research.google.com/github/mobassir94/comprehensive-bangla-tts/blob/main/mlt_TTS_inference_demo/v2_Multilingual_(bn%2Bar)_tts_based_Qtafsir_reader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# in this notebook we will be using arabic fastspeech2 along with bangla hifi gan vocoder based GlowTTS for multilingual book reading purpose,we will try to read tafsir bayan multilingual (bangla+arabic+english) code mixed tafsir of https://www.hadithbd.com/ with the help of our multilingual TTS pipeline.
#
# special thanks to
# 1. [Arabic fastspeech2](https://github.com/ARBML/klaam)
# 2. [Bangla glowtts](https://github.com/Open-Speech-EkStep/vakyansh-tts)

# %% [markdown]
# Based on our previous [notebook](https://github.com/mobassir94/comprehensive-bangla-tts/blob/main/mlt_TTS_inference_demo/bn-ar-tts-pipeline.ipynb)

# %%
# %%capture
# already installed
# !pip install --upgrade pip
# !pip install gdown==4.5.1
# !pip install bnunicodenormalizer==0.1.1
# # !pip install unidecode
# # !pip install numpy
# !pip install pydload==1.0.9
# !pip install pydub
# !nvidia-smi
# Out:
# Sun Oct 30 21:42:14 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.85.02    Driver Version: 510.85.02    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0  On |                  N/A |
# |  0%   55C    P8    34W / 370W |    258MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1504      G   /usr/lib/xorg/Xorg                 29MiB |
# |    0   N/A  N/A      2173      G   /usr/lib/xorg/Xorg                 89MiB |
# |    0   N/A  N/A      2304      G   /usr/bin/gnome-shell               43MiB |
# |    0   N/A  N/A      6740      G   ...RendererForSitePerProcess       36MiB |
# |    0   N/A  N/A      8216      G   ...671249456362434353,131072       42MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Download and clone necessary files

# %%
#/home/apsisdev/mobassir/data/tts/mlt_book_reader

# %%
import gdown
import torch
import os
import numpy as np

from IPython.display import Audio
import soundfile as sf
import shutil

import pandas as pd
from pydub import AudioSegment
import sys

memory=20109#/240 #(GPU total memory/number of cores)
os.environ["PYTORCH_CUDA_ALLOC_CONF"]="max_split_size_mb:{}".format(memory)

male = False

#https://www.kaggle.com/datasets/mobassir/bangla-quran-with-tafsir?select=ben_quran_with_tafsir.csv

q_tafsir = 'https://drive.google.com/drive/folders/1MJnVzKRCLzF_GLRkGALbHcLsHrNBl8xV?usp=sharing'
gdown.download_folder(url=q_tafsir, quiet=True)  


# !git clone https://github.com/Open-Speech-EkStep/vakyansh-tts
# !git clone https://github.com/ARBML/klaam

sys.path.append('/home/apsisdev/mobassir/data/tts/mlt_book_reader/klaam')


device = torch.device("cuda" if torch.cuda.is_available() else "cpu") #need cuda

device
# Out:
# fatal: destination path 'vakyansh-tts' already exists and is not an empty directory.
# fatal: destination path 'klaam' already exists and is not an empty directory.
# device(type='cuda')

# %%
torch.__version__
# Out:
# '1.12.1'

# %%
ls
# Out:
#  bn_qtafsir/     sample.wav
#  check_mlt.wav   tafsir_bayan/
#  empty.wav       temp.wav
#  klaam/         'v2_Multilingual_(bn+ar)_tts_based_Qtafsir_reader.ipynb'
#  model.pth.tar   vakyansh-tts/

# %% [markdown]
# # Bangla GlowTTS

# %%
#%%capture
#already installed
# ! pip install bnnumerizer
# ! pip install bangla==0.0.2
# ! pip install Unidecode
# ! pip install numpy

# %%
# os.chdir('vakyansh-tts') 

# #skipping next 3 line of codes as we have already pytorch latest version installed in this environment

# # !bash install.sh
# # !python setup.py bdist_wheel
# # !pip install -e .

# os.chdir('tts_infer')
# !mkdir translit_models
# os.chdir('translit_models')
# !wget https://storage.googleapis.com/vakyaansh-open-models/translit_models/default_lineup.json
# !mkdir bangla
# os.chdir('bangla')
# #https://storage.googleapis.com/vakyansh-open-models/translit_models.zip
# !wget https://storage.googleapis.com/vakyaansh-open-models/translit_models/bengali/bengali_transliteration.zip
# !unzip bengali_transliteration


# if(male):
#   print("male....")
#   !wget https://storage.googleapis.com/vakyansh-open-models/tts/bengali/bn-IN/male_voice_1/glow.zip
#   !unzip glow.zip

#   !wget https://storage.googleapis.com/vakyansh-open-models/tts/bengali/bn-IN/male_voice_1/hifi.zip
#   !unzip hifi.zip
# else:
#   print("female....")
#   !wget https://storage.googleapis.com/vakyansh-open-models/tts/bengali/bn-IN/female_voice_0/glow.zip
#   !unzip glow.zip

#   !wget https://storage.googleapis.com/vakyansh-open-models/tts/bengali/bn-IN/female_voice_0/hifi.zip
#   !unzip hifi.zip

# !rm glow.zip
# !rm hifi.zip

# %% [markdown]
# # Removing Annoying print statement during bangla TTS inference

# %%
# %%writefile /home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts/tts_infer/transliterate.py

import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import random
import sys
import os
import json
import enum
import traceback
import re

F_DIR = os.path.dirname(os.environ.get('translit_model_base_path', os.path.realpath(__file__)))


class XlitError(enum.Enum):
    lang_err = "Unsupported langauge ID requested ;( Please check available languages."
    string_err = "String passed is incompatable ;("
    internal_err = "Internal crash ;("
    unknown_err = "Unknown Failure"
    loading_err = "Loading failed ;( Check if metadata/paths are correctly configured."


##=================== Network ==================================================


class Encoder(nn.Module):
    def __init__(
        self,
        input_dim,
        embed_dim,
        hidden_dim,
        rnn_type="gru",
        layers=1,
        bidirectional=False,
        dropout=0,
        device="cpu",
    ):
        super(Encoder, self).__init__()

        self.input_dim = input_dim  # src_vocab_sz
        self.enc_embed_dim = embed_dim
        self.enc_hidden_dim = hidden_dim
        self.enc_rnn_type = rnn_type
        self.enc_layers = layers
        self.enc_directions = 2 if bidirectional else 1
        self.device = device

        self.embedding = nn.Embedding(self.input_dim, self.enc_embed_dim)

        if self.enc_rnn_type == "gru":
            self.enc_rnn = nn.GRU(
                input_size=self.enc_embed_dim,
                hidden_size=self.enc_hidden_dim,
                num_layers=self.enc_layers,
                bidirectional=bidirectional,
            )
        elif self.enc_rnn_type == "lstm":
            self.enc_rnn = nn.LSTM(
                input_size=self.enc_embed_dim,
                hidden_size=self.enc_hidden_dim,
                num_layers=self.enc_layers,
                bidirectional=bidirectional,
            )
        else:
            raise Exception("XlitError: unknown RNN type mentioned")

    def forward(self, x, x_sz, hidden=None):
        """
        x_sz: (batch_size, 1) -  Unpadded sequence lengths used for pack_pad
        """
        batch_sz = x.shape[0]
        # x: batch_size, max_length, enc_embed_dim
        x = self.embedding(x)

        ## pack the padded data
        # x: max_length, batch_size, enc_embed_dim -> for pack_pad
        x = x.permute(1, 0, 2)
        x = nn.utils.rnn.pack_padded_sequence(x, x_sz, enforce_sorted=False)  # unpad

        # output: packed_size, batch_size, enc_embed_dim
        # hidden: n_layer**num_directions, batch_size, hidden_dim | if LSTM (h_n, c_n)
        output, hidden = self.enc_rnn(
            x
        )  # gru returns hidden state of all timesteps as well as hidden state at last timestep

        ## pad the sequence to the max length in the batch
        # output: max_length, batch_size, enc_emb_dim*directions)
        output, _ = nn.utils.rnn.pad_packed_sequence(output)

        # output: batch_size, max_length, hidden_dim
        output = output.permute(1, 0, 2)

        return output, hidden

    def get_word_embedding(self, x):
        """ """
        x_sz = torch.tensor([len(x)])
        x_ = torch.tensor(x).unsqueeze(0).to(dtype=torch.long)
        # x: 1, max_length, enc_embed_dim
        x = self.embedding(x_)

        ## pack the padded data
        # x: max_length, 1, enc_embed_dim -> for pack_pad
        x = x.permute(1, 0, 2)
        x = nn.utils.rnn.pack_padded_sequence(x, x_sz, enforce_sorted=False)  # unpad

        # output: packed_size, 1, enc_embed_dim
        # hidden: n_layer**num_directions, 1, hidden_dim | if LSTM (h_n, c_n)
        output, hidden = self.enc_rnn(
            x
        )  # gru returns hidden state of all timesteps as well as hidden state at last timestep

        out_embed = hidden[0].squeeze()

        return out_embed


class Decoder(nn.Module):
    def __init__(
        self,
        output_dim,
        embed_dim,
        hidden_dim,
        rnn_type="gru",
        layers=1,
        use_attention=True,
        enc_outstate_dim=None,  # enc_directions * enc_hidden_dim
        dropout=0,
        device="cpu",
    ):
        super(Decoder, self).__init__()

        self.output_dim = output_dim  # tgt_vocab_sz
        self.dec_hidden_dim = hidden_dim
        self.dec_embed_dim = embed_dim
        self.dec_rnn_type = rnn_type
        self.dec_layers = layers
        self.use_attention = use_attention
        self.device = device
        if self.use_attention:
            self.enc_outstate_dim = enc_outstate_dim if enc_outstate_dim else hidden_dim
        else:
            self.enc_outstate_dim = 0

        self.embedding = nn.Embedding(self.output_dim, self.dec_embed_dim)

        if self.dec_rnn_type == "gru":
            self.dec_rnn = nn.GRU(
                input_size=self.dec_embed_dim
                + self.enc_outstate_dim,  # to concat attention_output
                hidden_size=self.dec_hidden_dim,  # previous Hidden
                num_layers=self.dec_layers,
                batch_first=True,
            )
        elif self.dec_rnn_type == "lstm":
            self.dec_rnn = nn.LSTM(
                input_size=self.dec_embed_dim
                + self.enc_outstate_dim,  # to concat attention_output
                hidden_size=self.dec_hidden_dim,  # previous Hidden
                num_layers=self.dec_layers,
                batch_first=True,
            )
        else:
            raise Exception("XlitError: unknown RNN type mentioned")

        self.fc = nn.Sequential(
            nn.Linear(self.dec_hidden_dim, self.dec_embed_dim),
            nn.LeakyReLU(),
            # nn.Linear(self.dec_embed_dim, self.dec_embed_dim), nn.LeakyReLU(), # removing to reduce size
            nn.Linear(self.dec_embed_dim, self.output_dim),
        )

        ##----- Attention ----------
        if self.use_attention:
            self.W1 = nn.Linear(self.enc_outstate_dim, self.dec_hidden_dim)
            self.W2 = nn.Linear(self.dec_hidden_dim, self.dec_hidden_dim)
            self.V = nn.Linear(self.dec_hidden_dim, 1)

    def attention(self, x, hidden, enc_output):
        """
        x: (batch_size, 1, dec_embed_dim) -> after Embedding
        enc_output: batch_size, max_length, enc_hidden_dim *num_directions
        hidden: n_layers, batch_size, hidden_size | if LSTM (h_n, c_n)
        """

        ## perform addition to calculate the score

        # hidden_with_time_axis: batch_size, 1, hidden_dim
        ## hidden_with_time_axis = hidden.permute(1, 0, 2) ## replaced with below 2lines
        hidden_with_time_axis = (
            torch.sum(hidden, axis=0)
            if self.dec_rnn_type != "lstm"
            else torch.sum(hidden[0], axis=0)
        )  # h_n

        hidden_with_time_axis = hidden_with_time_axis.unsqueeze(1)

        # score: batch_size, max_length, hidden_dim
        score = torch.tanh(self.W1(enc_output) + self.W2(hidden_with_time_axis))

        # attention_weights: batch_size, max_length, 1
        # we get 1 at the last axis because we are applying score to self.V
        attention_weights = torch.softmax(self.V(score), dim=1)

        # context_vector shape after sum == (batch_size, hidden_dim)
        context_vector = attention_weights * enc_output
        context_vector = torch.sum(context_vector, dim=1)
        # context_vector: batch_size, 1, hidden_dim
        context_vector = context_vector.unsqueeze(1)

        # attend_out (batch_size, 1, dec_embed_dim + hidden_size)
        attend_out = torch.cat((context_vector, x), -1)

        return attend_out, attention_weights

    def forward(self, x, hidden, enc_output):
        """
        x: (batch_size, 1)
        enc_output: batch_size, max_length, dec_embed_dim
        hidden: n_layer, batch_size, hidden_size | lstm: (h_n, c_n)
        """
        if (hidden is None) and (self.use_attention is False):
            raise Exception(
                "XlitError: No use of a decoder with No attention and No Hidden"
            )

        batch_sz = x.shape[0]

        if hidden is None:
            # hidden: n_layers, batch_size, hidden_dim
            hid_for_att = torch.zeros(
                (self.dec_layers, batch_sz, self.dec_hidden_dim)
            ).to(self.device)
        elif self.dec_rnn_type == "lstm":
            hid_for_att = hidden[1]  # c_n

        # x (batch_size, 1, dec_embed_dim) -> after embedding
        x = self.embedding(x)

        if self.use_attention:
            # x (batch_size, 1, dec_embed_dim + hidden_size) -> after attention
            # aw: (batch_size, max_length, 1)
            x, aw = self.attention(x, hidden, enc_output)
        else:
            x, aw = x, 0

        # passing the concatenated vector to the GRU
        # output: (batch_size, n_layers, hidden_size)
        # hidden: n_layers, batch_size, hidden_size | if LSTM (h_n, c_n)
        output, hidden = (
            self.dec_rnn(x, hidden) if hidden is not None else self.dec_rnn(x)
        )

        # output :shp: (batch_size * 1, hidden_size)
        output = output.view(-1, output.size(2))

        # output :shp: (batch_size * 1, output_dim)
        output = self.fc(output)

        return output, hidden, aw


class Seq2Seq(nn.Module):
    """
    Class dependency: Encoder, Decoder
    """

    def __init__(
        self, encoder, decoder, pass_enc2dec_hid=False, dropout=0, device="cpu"
    ):
        super(Seq2Seq, self).__init__()

        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        self.pass_enc2dec_hid = pass_enc2dec_hid
        _force_en2dec_hid_conv = False

        if self.pass_enc2dec_hid:
            assert (
                decoder.dec_hidden_dim == encoder.enc_hidden_dim
            ), "Hidden Dimension of encoder and decoder must be same, or unset `pass_enc2dec_hid`"
        if decoder.use_attention:
            assert (
                decoder.enc_outstate_dim
                == encoder.enc_directions * encoder.enc_hidden_dim
            ), "Set `enc_out_dim` correctly in decoder"
        assert (
            self.pass_enc2dec_hid or decoder.use_attention
        ), "No use of a decoder with No attention and No Hidden from Encoder"

        self.use_conv_4_enc2dec_hid = False
        if (
            self.pass_enc2dec_hid
            and (encoder.enc_directions * encoder.enc_layers != decoder.dec_layers)
        ) or _force_en2dec_hid_conv:
            if encoder.enc_rnn_type == "lstm" or encoder.enc_rnn_type == "lstm":
                raise Exception(
                    "XlitError: conv for enc2dec_hid not implemented; Change the layer numbers appropriately"
                )

            self.use_conv_4_enc2dec_hid = True
            self.enc_hid_1ax = encoder.enc_directions * encoder.enc_layers
            self.dec_hid_1ax = decoder.dec_layers
            self.e2d_hidden_conv = nn.Conv1d(self.enc_hid_1ax, self.dec_hid_1ax, 1)

    def enc2dec_hidden(self, enc_hidden):
        """
        enc_hidden: n_layer, batch_size, hidden_dim*num_directions
        TODO: Implement the logic for LSTm bsed model
        """
        # hidden: batch_size, enc_layer*num_directions, enc_hidden_dim
        hidden = enc_hidden.permute(1, 0, 2).contiguous()
        # hidden: batch_size, dec_layers, dec_hidden_dim -> [N,C,Tstep]
        hidden = self.e2d_hidden_conv(hidden)

        # hidden: dec_layers, batch_size , dec_hidden_dim
        hidden_for_dec = hidden.permute(1, 0, 2).contiguous()

        return hidden_for_dec

    def active_beam_inference(self, src, beam_width=3, max_tgt_sz=50):
        """Search based decoding
        src: (sequence_len)
        """

        def _avg_score(p_tup):
            """Used for Sorting
            TODO: Dividing by length of sequence power alpha as hyperparam
            """
            return p_tup[0]

        import sys

        batch_size = 1
        start_tok = src[0]
        end_tok = src[-1]
        src_sz = torch.tensor([len(src)])
        src_ = src.unsqueeze(0)

        # enc_output: (batch_size, padded_seq_length, enc_hidden_dim*num_direction)
        # enc_hidden: (enc_layers*num_direction, batch_size, hidden_dim)
        enc_output, enc_hidden = self.encoder(src_, src_sz)

        if self.pass_enc2dec_hid:
            # dec_hidden: dec_layers, batch_size , dec_hidden_dim
            if self.use_conv_4_enc2dec_hid:
                init_dec_hidden = self.enc2dec_hidden(enc_hidden)
            else:
                init_dec_hidden = enc_hidden
        else:
            # dec_hidden -> Will be initialized to zeros internally
            init_dec_hidden = None

        # top_pred[][0] = Σ-log_softmax
        # top_pred[][1] = sequence torch.tensor shape: (1)
        # top_pred[][2] = dec_hidden
        top_pred_list = [(0, start_tok.unsqueeze(0), init_dec_hidden)]

        for t in range(max_tgt_sz):
            cur_pred_list = []

            for p_tup in top_pred_list:
                if p_tup[1][-1] == end_tok:
                    cur_pred_list.append(p_tup)
                    continue

                # dec_hidden: dec_layers, 1, hidden_dim
                # dec_output: 1, output_dim
                dec_output, dec_hidden, _ = self.decoder(
                    x=p_tup[1][-1].view(1, 1),  # dec_input: (1,1)
                    hidden=p_tup[2],
                    enc_output=enc_output,
                )

                ## π{prob} = Σ{log(prob)} -> to prevent diminishing
                # dec_output: (1, output_dim)
                dec_output = nn.functional.log_softmax(dec_output, dim=1)
                # pred_topk.values & pred_topk.indices: (1, beam_width)
                pred_topk = torch.topk(dec_output, k=beam_width, dim=1)

                for i in range(beam_width):
                    sig_logsmx_ = p_tup[0] + pred_topk.values[0][i]
                    # seq_tensor_ : (seq_len)
                    seq_tensor_ = torch.cat((p_tup[1], pred_topk.indices[0][i].view(1)))

                    cur_pred_list.append((sig_logsmx_, seq_tensor_, dec_hidden))

            cur_pred_list.sort(key=_avg_score, reverse=True)  # Maximized order
            top_pred_list = cur_pred_list[:beam_width]

            # check if end_tok of all topk
            end_flags_ = [1 if t[1][-1] == end_tok else 0 for t in top_pred_list]
            if beam_width == sum(end_flags_):
                break

        pred_tnsr_list = [t[1] for t in top_pred_list]

        return pred_tnsr_list


##===================== Glyph handlers =======================================


class GlyphStrawboss:
    def __init__(self, glyphs="en"):
        """list of letters in a language in unicode
        lang: ISO Language code
        glyphs: json file with script information
        """
        if glyphs == "en":
            # Smallcase alone
            self.glyphs = [chr(alpha) for alpha in range(97, 122 + 1)]
        else:
            self.dossier = json.load(open(glyphs, encoding="utf-8"))
            self.glyphs = self.dossier["glyphs"]
            self.numsym_map = self.dossier["numsym_map"]

        self.char2idx = {}
        self.idx2char = {}
        self._create_index()

    def _create_index(self):

        self.char2idx["_"] = 0  # pad
        self.char2idx["$"] = 1  # start
        self.char2idx["#"] = 2  # end
        self.char2idx["*"] = 3  # Mask
        self.char2idx["'"] = 4  # apostrophe U+0027
        self.char2idx["%"] = 5  # unused
        self.char2idx["!"] = 6  # unused

        # letter to index mapping
        for idx, char in enumerate(self.glyphs):
            self.char2idx[char] = idx + 7  # +7 token initially

        # index to letter mapping
        for char, idx in self.char2idx.items():
            self.idx2char[idx] = char

    def size(self):
        return len(self.char2idx)

    def word2xlitvec(self, word):
        """Converts given string of gyphs(word) to vector(numpy)
        Also adds tokens for start and end
        """
        try:
            vec = [self.char2idx["$"]]  # start token
            for i in list(word):
                vec.append(self.char2idx[i])
            vec.append(self.char2idx["#"])  # end token

            vec = np.asarray(vec, dtype=np.int64)
            return vec

        except Exception as error:
            print("XlitError: In word:", word, "Error Char not in Token:", error)
            sys.exit()

    def xlitvec2word(self, vector):
        """Converts vector(numpy) to string of glyphs(word)"""
        char_list = []
        for i in vector:
            char_list.append(self.idx2char[i])

        word = "".join(char_list).replace("$", "").replace("#", "")  # remove tokens
        word = word.replace("_", "").replace("*", "")  # remove tokens
        return word


class VocabSanitizer:
    def __init__(self, data_file):
        """
        data_file: path to file conatining vocabulary list
        """
        extension = os.path.splitext(data_file)[-1]
        if extension == ".json":
            self.vocab_set = set(json.load(open(data_file, encoding="utf-8")))
        elif extension == ".csv":
            self.vocab_df = pd.read_csv(data_file).set_index("WORD")
            self.vocab_set = set(self.vocab_df.index)
        else:
            print("XlitError: Only Json/CSV file extension supported")

    def reposition(self, word_list):
        """Reorder Words in list"""
        new_list = []
        temp_ = word_list.copy()
        for v in word_list:
            if v in self.vocab_set:
                new_list.append(v)
                temp_.remove(v)
        new_list.extend(temp_)

        return new_list


##=============== INSTANTIATION ================================================


class XlitPiston:
    """
    For handling prediction & post-processing of transliteration for a single language
    Class dependency: Seq2Seq, GlyphStrawboss, VocabSanitizer
    Global Variables: F_DIR
    """

    def __init__(
        self,
        weight_path,
        vocab_file,
        tglyph_cfg_file,
        iglyph_cfg_file="en",
        device="cpu",
    ):

        self.device = device
        self.in_glyph_obj = GlyphStrawboss(iglyph_cfg_file)
        self.tgt_glyph_obj = GlyphStrawboss(glyphs=tglyph_cfg_file)
        self.voc_sanity = VocabSanitizer(vocab_file)

        self._numsym_set = set(
            json.load(open(tglyph_cfg_file, encoding="utf-8"))["numsym_map"].keys()
        )
        self._inchar_set = set("abcdefghijklmnopqrstuvwxyz")
        self._natscr_set = set().union(
            self.tgt_glyph_obj.glyphs, sum(self.tgt_glyph_obj.numsym_map.values(), [])
        )

        ## Model Config Static                TODO: add defining in json support
        input_dim = self.in_glyph_obj.size()
        output_dim = self.tgt_glyph_obj.size()
        enc_emb_dim = 300
        dec_emb_dim = 300
        enc_hidden_dim = 512
        dec_hidden_dim = 512
        rnn_type = "lstm"
        enc2dec_hid = True
        attention = True
        enc_layers = 1
        dec_layers = 2
        m_dropout = 0
        enc_bidirect = True
        enc_outstate_dim = enc_hidden_dim * (2 if enc_bidirect else 1)

        enc = Encoder(
            input_dim=input_dim,
            embed_dim=enc_emb_dim,
            hidden_dim=enc_hidden_dim,
            rnn_type=rnn_type,
            layers=enc_layers,
            dropout=m_dropout,
            device=self.device,
            bidirectional=enc_bidirect,
        )
        dec = Decoder(
            output_dim=output_dim,
            embed_dim=dec_emb_dim,
            hidden_dim=dec_hidden_dim,
            rnn_type=rnn_type,
            layers=dec_layers,
            dropout=m_dropout,
            use_attention=attention,
            enc_outstate_dim=enc_outstate_dim,
            device=self.device,
        )
        self.model = Seq2Seq(enc, dec, pass_enc2dec_hid=enc2dec_hid, device=self.device)
        self.model = self.model.to(self.device)
        weights = torch.load(weight_path, map_location=torch.device(self.device))

        self.model.load_state_dict(weights)
        self.model.eval()

    def character_model(self, word, beam_width=1):
        in_vec = torch.from_numpy(self.in_glyph_obj.word2xlitvec(word)).to(self.device)
        ## change to active or passive beam
        p_out_list = self.model.active_beam_inference(in_vec, beam_width=beam_width)
        p_result = [
            self.tgt_glyph_obj.xlitvec2word(out.cpu().numpy()) for out in p_out_list
        ]

        result = self.voc_sanity.reposition(p_result)

        # List type
        return result

    def numsym_model(self, seg):
        """tgt_glyph_obj.numsym_map[x] returns a list object"""
        if len(seg) == 1:
            return [seg] + self.tgt_glyph_obj.numsym_map[seg]

        a = [self.tgt_glyph_obj.numsym_map[n][0] for n in seg]
        return [seg] + ["".join(a)]

    def _word_segementer(self, sequence):

        sequence = sequence.lower()
        accepted = set().union(self._numsym_set, self._inchar_set, self._natscr_set)
        # sequence = ''.join([i for i in sequence if i in accepted])

        segment = []
        idx = 0
        seq_ = list(sequence)
        while len(seq_):
            # for Number-Symbol
            temp = ""
            while len(seq_) and seq_[0] in self._numsym_set:
                temp += seq_[0]
                seq_.pop(0)
            if temp != "":
                segment.append(temp)

            # for Target Chars
            temp = ""
            while len(seq_) and seq_[0] in self._natscr_set:
                temp += seq_[0]
                seq_.pop(0)
            if temp != "":
                segment.append(temp)

            # for Input-Roman Chars
            temp = ""
            while len(seq_) and seq_[0] in self._inchar_set:
                temp += seq_[0]
                seq_.pop(0)
            if temp != "":
                segment.append(temp)

            temp = ""
            while len(seq_) and seq_[0] not in accepted:
                temp += seq_[0]
                seq_.pop(0)
            if temp != "":
                segment.append(temp)

        return segment

    def inferencer(self, sequence, beam_width=10):

        seg = self._word_segementer(sequence[:120])
        lit_seg = []

        p = 0
        while p < len(seg):
            if seg[p][0] in self._natscr_set:
                lit_seg.append([seg[p]])
                p += 1

            elif seg[p][0] in self._inchar_set:
                lit_seg.append(self.character_model(seg[p], beam_width=beam_width))
                p += 1

            elif seg[p][0] in self._numsym_set:  # num & punc
                lit_seg.append(self.numsym_model(seg[p]))
                p += 1
            else:
                lit_seg.append([seg[p]])
                p += 1

        ## IF segment less/equal to 2 then return combinotorial,
        ## ELSE only return top1 of each result concatenated
        if len(lit_seg) == 1:
            final_result = lit_seg[0]

        elif len(lit_seg) == 2:
            final_result = [""]
            for seg in lit_seg:
                new_result = []
                for s in seg:
                    for f in final_result:
                        new_result.append(f + s)
                final_result = new_result

        else:
            new_result = []
            for seg in lit_seg:
                new_result.append(seg[0])
            final_result = ["".join(new_result)]

        return final_result


from collections.abc import Iterable
from pydload import dload
import zipfile

MODEL_DOWNLOAD_URL_PREFIX = "https://github.com/AI4Bharat/IndianNLP-Transliteration/releases/download/xlit_v0.5.0/"


def is_folder_writable(folder):
    try:
        os.makedirs(folder, exist_ok=True)
        tmp_file = os.path.join(folder, ".write_test")
        with open(tmp_file, "w") as f:
            f.write("Permission Check")
        os.remove(tmp_file)
        return True
    except:
        return False


def is_directory_writable(path):
    if os.name == "nt":
        return is_folder_writable(path)
    return os.access(path, os.W_OK | os.X_OK)


class XlitEngine:
    """
    For Managing the top level tasks and applications of transliteration
    Global Variables: F_DIR
    """

    def __init__(
        self, lang2use="all", config_path="translit_models/default_lineup.json"
    ):

        lineup = json.load(open(os.path.join(F_DIR, config_path), encoding="utf-8"))
        self.lang_config = {}
        if isinstance(lang2use, str):
            if lang2use == "all":
                self.lang_config = lineup
            elif lang2use in lineup:
                self.lang_config[lang2use] = lineup[lang2use]
            else:
                raise Exception(
                    "XlitError: The entered Langauge code not found. Available are {}".format(
                        lineup.keys()
                    )
                )

        elif isinstance(lang2use, Iterable):
            for l in lang2use:
                try:
                    self.lang_config[l] = lineup[l]
                except:
                    print(
                        "XlitError: Language code {} not found, Skipping...".format(l)
                    )
        else:
            raise Exception(
                "XlitError: lang2use must be a list of language codes (or) string of single language code"
            )

        if is_directory_writable(F_DIR):
            models_path = os.path.join(F_DIR, "translit_models")
        else:
            user_home = os.path.expanduser("~")
            models_path = os.path.join(user_home, ".AI4Bharat_Xlit_Models")
        os.makedirs(models_path, exist_ok=True)
        self.download_models(models_path)

        self.langs = {}
        self.lang_model = {}
        for la in self.lang_config:
            try:
                #print("Loading {}...".format(la))
                self.lang_model[la] = XlitPiston(
                    weight_path=os.path.join(
                        models_path, self.lang_config[la]["weight"]
                    ),
                    vocab_file=os.path.join(models_path, self.lang_config[la]["vocab"]),
                    tglyph_cfg_file=os.path.join(
                        models_path, self.lang_config[la]["script"]
                    ),
                    iglyph_cfg_file="en",
                )
                self.langs[la] = self.lang_config[la]["name"]
            except Exception as error:
                print("XlitError: Failure in loading {} \n".format(la), error)
                print(XlitError.loading_err.value)

    def download_models(self, models_path):
        """
        Download models from GitHub Releases if not exists
        """
        for l in self.lang_config:
            lang_name = self.lang_config[l]["eng_name"]
            lang_model_path = os.path.join(models_path, lang_name)
            if not os.path.isdir(lang_model_path):
                print("Downloading model for language: %s" % lang_name)
                remote_url = MODEL_DOWNLOAD_URL_PREFIX + lang_name + ".zip"
                downloaded_zip_path = os.path.join(models_path, lang_name + ".zip")
                dload(url=remote_url, save_to_path=downloaded_zip_path, max_time=None)

                if not os.path.isfile(downloaded_zip_path):
                    exit(
                        f"ERROR: Unable to download model from {remote_url} into {models_path}"
                    )

                with zipfile.ZipFile(downloaded_zip_path, "r") as zip_ref:
                    zip_ref.extractall(models_path)

                if os.path.isdir(lang_model_path):
                    os.remove(downloaded_zip_path)
                else:
                    exit(
                        f"ERROR: Unable to find models in {lang_model_path} after download"
                    )
        return

    def translit_word(self, eng_word, lang_code="default", topk=7, beam_width=10):
        if eng_word == "":
            return []

        if lang_code in self.langs:
            try:
                res_list = self.lang_model[lang_code].inferencer(
                    eng_word, beam_width=beam_width
                )
                return res_list[:topk]

            except Exception as error:
                print("XlitError:", traceback.format_exc())
                print(XlitError.internal_err.value)
                return XlitError.internal_err

        elif lang_code == "default":
            try:
                res_dict = {}
                for la in self.lang_model:
                    res = self.lang_model[la].inferencer(
                        eng_word, beam_width=beam_width
                    )
                    res_dict[la] = res[:topk]
                return res_dict

            except Exception as error:
                print("XlitError:", traceback.format_exc())
                print(XlitError.internal_err.value)
                return XlitError.internal_err

        else:
            print("XlitError: Unknown Langauge requested", lang_code)
            print(XlitError.lang_err.value)
            return XlitError.lang_err

    def translit_sentence(self, eng_sentence, lang_code="default", beam_width=10):
        if eng_sentence == "":
            return []

        if lang_code in self.langs:
            try:
                out_str = ""
                for word in eng_sentence.split():
                    res_ = self.lang_model[lang_code].inferencer(
                        word, beam_width=beam_width
                    )
                    out_str = out_str + res_[0] + " "
                return out_str[:-1]

            except Exception as error:
                print("XlitError:", traceback.format_exc())
                print(XlitError.internal_err.value)
                return XlitError.internal_err

        elif lang_code == "default":
            try:
                res_dict = {}
                for la in self.lang_model:
                    out_str = ""
                    for word in eng_sentence.split():
                        res_ = self.lang_model[la].inferencer(
                            word, beam_width=beam_width
                        )
                        out_str = out_str + res_[0] + " "
                    res_dict[la] = out_str[:-1]
                return res_dict

            except Exception as error:
                print("XlitError:", traceback.format_exc())
                print(XlitError.internal_err.value)
                return XlitError.internal_err

        else:
            print("XlitError: Unknown Langauge requested", lang_code)
            print(XlitError.lang_err.value)
            return XlitError.lang_err


if __name__ == "__main__":

    available_lang = [
        "bn",
        "gu",
        "hi",
        "kn",
        "gom",
        "mai",
        "ml",
        "mr",
        "pa",
        "sd",
        "si",
        "ta",
        "te",
        "ur",
    ]

    reg = re.compile(r"[a-zA-Z]")
    lang = "hi"
    engine = XlitEngine(
        lang
    )  # if you don't specify lang code here, this will give results in all langs available
    sent = "Hello World! ABCD क्या हाल है आपका?"
    words = [
        engine.translit_word(word, topk=1)[lang][0] if reg.match(word) else word
        for word in sent.split()
    ]  # only transliterated en words, leaves rest as it is
    updated_sent = " ".join(words)

    print(updated_sent)

    # output : हेलो वर्ल्ड! क्या हाल है आपका?

    # y = engine.translit_sentence("Hello World !")['hi']
    # print(y)
# Out:
# Overwriting /home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts/tts_infer/transliterate.py

# %% [markdown]
# # Bengali TTS inference demo

# %%
# os.chdir('/content/vakyansh-tts/')
# !pip install inflect
sys.path.append('/home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts')
import bangla
from tts_infer.tts import TextToMel, MelToWav
from tts_infer.transliterate import XlitEngine
from tts_infer.num_to_word_on_sent import normalize_nums

import re
from scipy.io.wavfile import write

text_to_mel = TextToMel(glow_model_dir='/home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts/tts_infer/translit_models/bangla/glow_ckp', device=device)
mel_to_wav = MelToWav(hifi_model_dir='/home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts/tts_infer/translit_models/bangla/hifi_ckp', device=device)

def translit(text, lang):
    reg = re.compile(r'[a-zA-Z]')
    engine = XlitEngine(lang)
    words = [engine.translit_word(word, topk=1)[lang][0] if reg.match(word) else word for word in text.split()]
    updated_sent = ' '.join(words)
    return updated_sent
    
def run_tts(text, lang):
    # text = text.replace('।', '.') # only for hindi models
    text_num_to_word = normalize_nums(text, lang) # converting numbers to words in lang
    text_num_to_word_and_transliterated = translit(text_num_to_word, lang) # transliterating english words to lang
    
    mel = text_to_mel.generate_mel(text_num_to_word_and_transliterated)
    audio, sr = mel_to_wav.generate_wav(mel)
    write(filename='temp.wav', rate=sr, data=audio) # for saving wav file, if needed
    return (sr, audio)

def ben_tts(text, lang):
    # text = text.replace('।', '.') # only for hindi models
    text_num_to_word = normalize_nums(text, lang) # converting numbers to words in lang
    text_num_to_word_and_transliterated = translit(text_num_to_word, lang) # transliterating english words to lang
    
    mel = text_to_mel.generate_mel(text_num_to_word_and_transliterated)
    audio, sr = mel_to_wav.generate_wav(mel)
    del mel,text_num_to_word_and_transliterated,text_num_to_word
    return audio
# Out:
# Requirement already satisfied: inflect in /home/apsisdev/anaconda3/envs/kaggle/lib/python3.8/site-packages (6.0.2)
# Requirement already satisfied: pydantic>=1.9.1 in /home/apsisdev/anaconda3/envs/kaggle/lib/python3.8/site-packages (from inflect) (1.10.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/apsisdev/anaconda3/envs/kaggle/lib/python3.8/site-packages (from pydantic>=1.9.1->inflect) (4.3.0)
# /home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts/tts_infer/translit_models/bangla/glow_ckp/G_263.pth
# /home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts/tts_infer/../src/glow_tts/modules.py:234: UserWarning: torch.qr is deprecated in favor of torch.linalg.qr and will be removed in a future PyTorch release.
# The boolean parameter 'some' has been replaced with a string parameter 'mode'.
# Q, R = torch.qr(A, some)
# should be replaced with
# Q, R = torch.linalg.qr(A, 'reduced' if some else 'complete') (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484683044/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2491.)
#   w_init = torch.qr(torch.FloatTensor(self.n_split, self.n_split).normal_())[0]
# INFO:root:Loaded checkpoint '/home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts/tts_infer/translit_models/bangla/glow_ckp/G_263.pth' (iteration 263)
# /home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts/tts_infer/translit_models/bangla/hifi_ckp/g_00100000
# Loading '/home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts/tts_infer/translit_models/bangla/hifi_ckp/g_00100000'
# Complete.
# Removing weight norm...

# %%
# !pwd
# Out:
# /home/apsisdev/mobassir/data/tts/mlt_book_reader

# %%
os.chdir('/home/apsisdev/mobassir/data/tts/mlt_book_reader/')

# %%
# !pwd
# Out:
# /home/apsisdev/mobassir/data/tts/mlt_book_reader

# %%
_, audio = run_tts('বিসমিল্লাহ’র পূর্বে ‘আক্বরাউ’ ‘আবদাউ’ অথবা ‘আতলু’ ফে’ল ক্রিয়া উহ্য আছে। অর্থাৎ, আল্লাহর নাম নিয়ে পড়ছি  কিংবা তেলাঅত আরম্ভ করছি। ', 'bn')
Audio('temp.wav')
# Out:
# /home/apsisdev/mobassir/data/tts/mlt_book_reader/vakyansh-tts/tts_infer/../src/glow_tts/models.py:399: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   y_lengths = (y_lengths // self.n_sqz) * self.n_sqz
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !nvidia-smi
# Out:
# Sun Oct 30 21:42:27 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.85.02    Driver Version: 510.85.02    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0  On |                  N/A |
# |  0%   59C    P2   124W / 370W |   1966MiB / 24576MiB |     53%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1504      G   /usr/lib/xorg/Xorg                 29MiB |
# |    0   N/A  N/A      2173      G   /usr/lib/xorg/Xorg                 89MiB |
# |    0   N/A  N/A      2304      G   /usr/bin/gnome-shell               43MiB |
# |    0   N/A  N/A      6740      G   ...RendererForSitePerProcess       36MiB |
# |    0   N/A  N/A      8216      G   ...671249456362434353,131072       34MiB |
# |    0   N/A  N/A   2390639      C   ...a3/envs/kaggle/bin/python     1713MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Arabic FastSpeech2 TTS

# %%
os.chdir('klaam')

# %%
#%%capture
#!pip install pyarabic

#!pip install -r requirements.txt

# %%
os.chdir('/home/apsisdev/mobassir/data/tts/mlt_book_reader') 
from klaam import TextToSpeech
from pyarabic.araby import strip_diacritics
root_path = "/home/apsisdev/mobassir/data/tts/mlt_book_reader/klaam/"
prepare_tts_model_path = "/home/apsisdev/mobassir/data/tts/mlt_book_reader/klaam/cfgs/FastSpeech2/config/Arabic/preprocess.yaml"
model_config_path = "/home/apsisdev/mobassir/data/tts/mlt_book_reader/klaam/cfgs/FastSpeech2/config/Arabic/model.yaml"
train_config_path = "/home/apsisdev/mobassir/data/tts/mlt_book_reader/klaam/cfgs/FastSpeech2/config/Arabic/train.yaml"
vocoder_config_path = "/home/apsisdev/mobassir/data/tts/mlt_book_reader/klaam/cfgs/FastSpeech2/model_config/hifigan/config.json"
speaker_pre_trained_path = "/home/apsisdev/mobassir/data/tts/mlt_book_reader/klaam/data/model_weights/hifigan/generator_universal.pth.tar"

ar_model = TextToSpeech(prepare_tts_model_path, model_config_path, train_config_path, vocoder_config_path, speaker_pre_trained_path,root_path)
# Out:
# Removing weight norm...

# %%
text = "ٱلۡحَمۡدُ لِلَّهِ رَبِّ ٱلۡعَٰلَمِينَ"

ar_model.synthesize(text)

#sf.write('sound.wav', wave, 22050)
Audio('./sample.wav')
# Out:
# Raw Text Sequence: ٱلۡحَمۡدُ لِلَّهِ رَبِّ ٱلۡعَٰلَمِينَ
# Phoneme Sequence: {l H a m d u0 l i0 ll a h i0 r a bb i0 l E a l a m ii0 n a sil}
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # TTS BigTextToAudio
#
# long text to audio conversion

# %%
import re
import torchaudio.functional as F
import torchaudio
from bnnumerizer import numerize
import gc
from bnunicodenormalizer import Normalizer 
# initialize
bnorm=Normalizer()

# Create empty audio file of half second duration (purpose -> post processing)

audio = AudioSegment.silent(duration=500)
sound = audio.set_frame_rate(audio.frame_rate*2)
sound.export("/home/apsisdev/mobassir/data/tts/mlt_book_reader/empty.wav", format="wav")

#loading empty audio file of  1 second to append before and after each arabic chunk for increasing mlt reading rhythm.

empty_audio, rate_of_sample = torchaudio.load('/home/apsisdev/mobassir/data/tts/mlt_book_reader/empty.wav')
empty_audio = empty_audio.flatten()

def normalize(sen):
    _words = [bnorm(word)['normalized']  for word in sen.split()]
    return " ".join([word for word in _words if word is not None]) 

class BigTextToAudio(object):
    
    def __init__(self,
                 ar_model,
                 bn_model,
                 ar_sample_rate=22050,
                 bn_sample_rate=22050,
                 out_sample_rate=22050,
                 attribution_dict={"সাঃ":"সাল্লাল্লাহু আলাইহি ওয়া সাল্লাম",                   
                                  "আঃ":"আলাইহিস সালাম",
                                  "রাঃ":"রাদিআল্লাহু আনহু",
                                  "রহঃ":"রহমাতুল্লাহি আলাইহি",
                                  "রহিঃ":"রহিমাহুল্লাহ",
                                  "হাফিঃ":"হাফিযাহুল্লাহ",
                                  "বায়ান":"বাইআন",
                                  "দাঃবাঃ":"দামাত বারাকাতুহুম,দামাত বারাকাতুল্লাহ",
                                  "আয়াত" : "আইআত",#আইআত
                                  # "ওয়া" : "ওআ",
                                  # "ওয়াসাল্লাম"  : "ওআসাল্লাম",
                                  # "কেন"  : "কেনো",
                                  # "কোন" : "কোনো",
                                  # "বল"   : "বলো",
                                  # "চল"   : "চলো",
                                  # "কর"   : "করো",
                                  # "রাখ"   : "রাখো",
                                  "’"     :  "",
                                  "‘"     : "",
                                  # "য়"     : "অ",
                                  # "সম্প্রদায়" : "সম্প্রদাই",
                                  # "রয়েছে"   : "রইছে",
                                  # "রয়েছ"    : "রইছ",
                                   "/"   : " বাই ",
                                  },
                resample_params={"lowpass_filter_width": 64,
                                "rolloff": 0.9475937167399596,
                                "resampling_method": "kaiser_window",
                                "beta": 14.769656459379492}
                ):
        '''
            Instantiates a Big Text to Audio conversion object for bangla and arabic
            args:
                ar_model : arabic tts model
                bn_model : bangla tts model
                ar_sample_rate : arabic audio sample rate [optional] default: 22050
                bn_sample_rate : bangla audio sample rate [optional] default: 22050
                out_sample_rate : audio sample rate [optional] default: 22050
                attribution_dict : a dict for attribution expansion [optional]
                resample_params : audio resampling parameters [optional]
            resources:
                # Main class: modified from https://github.com/snakers4/silero-models/pull/174
                # Audio converter:https://www.kaggle.com/code/shahruk10/inference-notebook-wav2vec2
        '''
        self.ar_model = ar_model
        self.bn_model = bn_model
        self.attribution_dict=attribution_dict
 
        self.ar_sample_rate=ar_sample_rate
        self.bn_sample_rate=bn_sample_rate
        self.sample_rate=out_sample_rate  
        self.resample_params=resample_params
        
    # public
    def ar_tts(self,text):
        '''
            args: 
                text: arabic text (string)
            returns:
                audio as torch tensor
        '''
#         from pyarabic.araby import tokenize, is_arabicrange, strip_tashkeel
#         print("before ",text)
#         text = tokenize(text, conditions=is_arabicrange, morphs=strip_tashkeel)
        
#         text = ' '.join(text)
#         print(len(text),text)
        text = strip_diacritics(text)

        try:
            self.ar_model.synthesize(text)
            audio, rate_of_sample = torchaudio.load('/home/apsisdev/mobassir/data/tts/mlt_book_reader/sample.wav')
            audio = audio.flatten()
            audio = torch.cat([empty_audio,audio], axis=0) #start empty
            audio = torch.cat([audio,empty_audio], axis=0) #end empty
            audio = audio * 32768.0
        except:
            print("--------------------->>>>>>>>>>>>>>>>>>>>>>>>>>>    failed ar =>",text," end")
            audio=self.bn_tts(text)
            #audio = empty_audio * 32768.0
                  
        
        return audio
    # public
    def bn_tts(self,text):
        '''
            args: 
                text   : bangla text (string)
            returns:
                audio as torch tensor
        '''
        
        if(self.bn_model == 'glowtts'):
          audio = ben_tts(text, 'bn')
          #audio = torch.from_numpy(audio)

        else:
          print("not supported!")

        return torch.tensor(audio)
    
    # public
    def expand_full_attribution(self,text):
        for word in self.attribution_dict:
            if word in text:
                text = text.replace(word, normalize(self.attribution_dict[word]))
        return text
    
    def collapse_whitespace(self,text):
        # Regular expression matching whitespace:
        _whitespace_re = re.compile(r"\s+")
        return re.sub(_whitespace_re, " ", text)

    # public
    def tag_text(self,text):
        '''
            * tags arabic text with <ar>text</ar>
            * tags bangla text with <bn>text</bn>
        '''
        # remove multiple spaces
        text=re.sub(' +', ' ',text)
        # create start and end
        text="start"+text+"end"
        # tag text
        parts=re.split(u'[\u0600-\u06FF]+', text)
        # remove non chars
        parts=[p for p in parts if p.strip()]
        # unique parts
        parts=set(parts)
        # tag the text
        for m in parts:
            if len(m.strip())>1:text=text.replace(m,f"</ar><SPLIT><bn>{m}</bn><SPLIT><ar>")
        # clean-tags
        text=text.replace("</ar><SPLIT><bn>start",'<bn>')
        text=text.replace("end</bn><SPLIT><ar>",'</bn>')
        return text

    def process_text(self,text):
        '''
        process multilingual text for suitable MLT TTS format
            * expand attributions
            * numerize text
            * tag sections of the text
            * sequentially list text blocks
            * Split based on sentence ending Characters

        '''
        
        # english numbers to bangla conversion
        res = re.search('[0-9]', text)
        if res is not None:
          text = bangla.convert_english_digit_to_bangla_digit(text)
        
        #replace ':' in between two bangla numbers with ' এর '
        pattern=r"[০, ১, ২, ৩, ৪, ৫, ৬, ৭, ৮, ৯]:[০, ১, ২, ৩, ৪, ৫, ৬, ৭, ৮, ৯]"
        matches=re.findall(pattern,text)
        for m in matches:
            r=m.replace(":"," এর ")
            text=text.replace(m,r)

        # numerize text
        try:
            text=numerize(text)
        except:
            print("couldn't numerize ",text)

        # tag sections
#         text=self.tag_text(text)
        text="।".join([self.tag_text(line) for line in text.split("।")])
        # text blocks
        blocks=text.split("<SPLIT>")
        blocks=[b for b in blocks if b.strip()]
        # create tuple of (lang,text)
        data=[]
        for block in blocks:
            lang=None
            if "<bn>" in block:
                block=block.replace("<bn>",'').replace("</bn>",'')
                lang="bn"
            elif "<ar>" in block:
                block=block.replace("<ar>",'').replace("</ar>",'')
                lang="ar"
            
            # Split based on sentence ending Characters

            if lang == "bn":
              bn_text = block.strip()

              sentenceEnders = re.compile('[।!?]')
              sentences = sentenceEnders.split(str(bn_text))

              for i in range(len(sentences)):
                    res = re.sub('\n','',sentences[i])
                    res = normalize(res)
                    # expand attributes
                    res=self.expand_full_attribution(res)

                    res = self.collapse_whitespace(res)
                    res += '।'
                    if(len(res)>500):
                        firstpart, secondpart = res[:len(res)//2], res[len(res)//2:]
                        data.append((lang,firstpart))
                        data.append((lang,secondpart))
                    else:
                        data.append((lang,res))

            elif lang == "ar":
                ar_text = block.strip()
                ar_text = re.sub("؟", "?", ar_text) # replace any ؟ with ?

                sentenceEnders = re.compile('[.।!,?]')
                sentences = sentenceEnders.split(str(ar_text))

                for i in range(len(sentences)):
                    res = re.sub('\n','',sentences[i])
                    res = self.collapse_whitespace(res)
                    if(len(res)>500):
                      firstpart, secondpart = res[:len(res)//2], res[len(res)//2:]
                      data.append((lang,firstpart))
                      data.append((lang,secondpart))
                    else:
                      data.append((lang,res))
                    
        return data
    
    def resample_audio(self,audio,sr):
        '''
            resample audio with sample rate
            args:
                audio : torch.tensor audio
                sr: audi sample rate
        '''
        if sr==self.sample_rate:
            return audio
        else:
            return F.resample(audio,sr,self.sample_rate,**self.resample_params)
        
    
    def get_audio(self,data):
        '''
            creates audio from given data 
                * data=List[Tuples(lang,text)]
        '''
        audio_list = []
        for block in data:
            lang,text=block
            if lang=="bn":
                audio=self.bn_tts(text)
                sr=self.bn_sample_rate
            else:
                audio=self.ar_tts(text)
                sr=self.ar_sample_rate
            
            if self.resample_audio_to_out_sample_rate:
                audio=self.resample_audio(audio,sr)
                
            audio_list.append(audio)
  
        audio = torch.cat([k for k in audio_list])
        return audio
    
    # call
    def __call__(self,text,resample_audio_to_out_sample_rate=True):
        '''
            args: 
                text   : bangla text (string)
                resample_audio_to_out_sample_rate: for different sample rate in different models, resample the output audio 
                                                   in uniform sample rate 
                                                   * default:True
            returns:
                audio as numpy data
        '''
        self.resample_audio_to_out_sample_rate=resample_audio_to_out_sample_rate
        data=self.process_text(text)
        audio=self.get_audio(data)
        return audio.detach().cpu().numpy()

# %% [markdown]
# # check textprocessing

# %%
df = pd.read_csv('/home/apsisdev/mobassir/data/tts/mlt_book_reader/bn_qtafsir/ben_quran_with_tafsir.csv')
text = df.tafsir_bayan_text[1]

text = '''সুরা ৪, আয়াত  ১ এর বাংলা অনুবাদ পরছি। হে মানুষ, তোমরা তোমাদের রবকে ভয় কর, যিনি তোমাদেরকে সৃষ্টি করেছেন এক নফ্স থেকে। আর তা থেকে সৃষ্টি করেছেন তার স্ত্রীকে এবং তাদের থেকে ছড়িয়ে দিয়েছেন বহু পুরুষ ও নারী। আর তোমরা আল্লাহকে ভয় কর, যার মাধ্যমে তোমরা একে অপরের কাছে চেয়ে থাক। আর ভয় কর রক্ত-সম্পর্কিত আত্মীয়ের ব্যাপারে। নিশ্চয় আল্লাহ তোমাদের উপর পর্যবেক্ষক।  ।  আয়াত টির বাংলা তাফসির পরছি।  [1] ‘একটি প্রাণ’ বলতে মানবকুলের পিতা আদম (আঃ)-কে বুঝানো হয়েছে। আর خَلَقَ مِنْهَا زَوْجَهَا এতে مِنْهَا থেকে উক্ত প্রাণ অর্থাৎ, আদম (আঃ)-কেই বুঝানো হয়েছে। অর্থাৎ, আদম (আঃ) থেকেই তাঁর স্ত্রী হাওয়াকে সৃষ্টি করেন। আদম (আঃ) থেকে হাওয়াকে কিভাবে সৃষ্টি করা হয়, এ ব্যাপারে মতভেদ রয়েছে। ইবনে আব্বাস (রাঃ) থেকে বর্ণিত যে, হাওয়া পুরুষ অর্থাৎ, আদম (আঃ) থেকে সৃষ্টি হয়েছেন। অর্থাৎ, তাঁর পাঁজরের হাড় থেকে। অপর একটি হাদীসে বলা হয়েছে যে, ‘‘নারীদেরকে পাঁজরের হাড় থেকে সৃষ্টি করা হয়েছে। আর পাঁজরের হাড়ের মধ্যে উপরের হাড়টি অধিক বাঁকা। যদি তা সোজা করতে যাও, তাহলে ভেঙ্গে ফেলবে। আর যদি তুমি তার দ্বারা উপকৃত হতে চাও, তবে তার মধ্যে বক্রতা অবশিষ্ট থাকা অবস্থাতেই উপকৃত হতে পারবে।’’ (বুখারী ৩৩৩১, মুসলিম ১৪৬৮নং) উলামাদের কেউ কেউ এই হাদীসের ভিত্তিতে ইবনে আব্বাস (রাঃ) থেকে বর্ণিত উক্তিকেই সমর্থন করেছেন। কুরআনের শব্দ خَلَقَ مِنْهَا থেকেও এই মতের সমর্থন হয়। অর্থাৎ, মা হাওয়ার সৃষ্টি সেই একটি প্রাণ থেকেই হয়েছে, যাকে ‘আদম’ বলা হয়।[2] وَالأَرْحَامَ এর সংযোগ اللَّهَ এর সাথে। অর্থাৎ, আত্মীয়তার সম্পর্ক ছিন্ন করাকেও ভয় কর। أَرْحَامٌ  হলো, رِحِمٌ এর বহুবচন। যার অর্থ হল গর্ভাশয়, যেহেতু আত্মীয়তার সম্পর্ক মাতৃগর্ভের ভিত্তিতেই কায়েম হয়। এতে মাহরাম (যার সাথে চিরতরের জন্য বিবাহ হারাম, অগম্য বা এগানা) এবং গায়র মাহরাম (গম্য বা বেগানা) সকল আত্মীয়ই শামিল। আত্মীয়তার সম্পর্ক ছিন্ন করা অতি বড় গোনাহ। হাদীসসমূহে সর্বাবস্থায় আত্মীয়তার সম্পর্ক কায়েম রাখার এবং তাদের অধিকার আদায় করার প্রতি বড়ই তাকীদ করা হয়েছে এবং এ কাজের অনেক ফযীলতের কথাও বর্ণিত হয়েছে।তাফসীরে আহসানুল বায়ান'''
print(text)
bn_model = 'glowtts'
MLT_TTS=BigTextToAudio(ar_model=ar_model,
                   bn_model=bn_model)

data=MLT_TTS.process_text(text)
data
# Out:
# সুরা ৪, আয়াত  ১ এর বাংলা অনুবাদ পরছি। হে মানুষ, তোমরা তোমাদের রবকে ভয় কর, যিনি তোমাদেরকে সৃষ্টি করেছেন এক নফ্স থেকে। আর তা থেকে সৃষ্টি করেছেন তার স্ত্রীকে এবং তাদের থেকে ছড়িয়ে দিয়েছেন বহু পুরুষ ও নারী। আর তোমরা আল্লাহকে ভয় কর, যার মাধ্যমে তোমরা একে অপরের কাছে চেয়ে থাক। আর ভয় কর রক্ত-সম্পর্কিত আত্মীয়ের ব্যাপারে। নিশ্চয় আল্লাহ তোমাদের উপর পর্যবেক্ষক।  ।  আয়াত টির বাংলা তাফসির পরছি।  [1] ‘একটি প্রাণ’ বলতে মানবকুলের পিতা আদম (আঃ)-কে বুঝানো হয়েছে। আর خَلَقَ مِنْهَا زَوْجَهَا এতে مِنْهَا থেকে উক্ত প্রাণ অর্থাৎ, আদম (আঃ)-কেই বুঝানো হয়েছে। অর্থাৎ, আদম (আঃ) থেকেই তাঁর স্ত্রী হাওয়াকে সৃষ্টি করেন। আদম (আঃ) থেকে হাওয়াকে কিভাবে সৃষ্টি করা হয়, এ ব্যাপারে মতভেদ রয়েছে। ইবনে আব্বাস (রাঃ) থেকে বর্ণিত যে, হাওয়া পুরুষ অর্থাৎ, আদম (আঃ) থেকে সৃষ্টি হয়েছেন। অর্থাৎ, তাঁর পাঁজরের হাড় থেকে। অপর একটি হাদীসে বলা হয়েছে যে, ‘‘নারীদেরকে পাঁজরের হাড় থেকে সৃষ্টি করা হয়েছে। আর পাঁজরের হাড়ের মধ্যে উপরের হাড়টি অধিক বাঁকা। যদি তা সোজা করতে যাও, তাহলে ভেঙ্গে ফেলবে। আর যদি তুমি তার দ্বারা উপকৃত হতে চাও, তবে তার মধ্যে বক্রতা অবশিষ্ট থাকা অবস্থাতেই উপকৃত হতে পারবে।’’ (বুখারী ৩৩৩১, মুসলিম ১৪৬৮নং) উলামাদের কেউ কেউ এই হাদীসের ভিত্তিতে ইবনে আব্বাস (রাঃ) থেকে বর্ণিত উক্তিকেই সমর্থন করেছেন। কুরআনের শব্দ خَلَقَ مِنْهَا থেকেও এই মতের সমর্থন হয়। অর্থাৎ, মা হাওয়ার সৃষ্টি সেই একটি প্রাণ থেকেই হয়েছে, যাকে ‘আদম’ বলা হয়।[2] وَالأَرْحَامَ এর সংযোগ اللَّهَ এর সাথে। অর্থাৎ, আত্মীয়তার সম্পর্ক ছিন্ন করাকেও ভয় কর। أَرْحَامٌ  হলো, رِحِمٌ এর বহুবচন। যার অর্থ হল গর্ভাশয়, যেহেতু আত্মীয়তার সম্পর্ক মাতৃগর্ভের ভিত্তিতেই কায়েম হয়। এতে মাহরাম (যার সাথে চিরতরের জন্য বিবাহ হারাম, অগম্য বা এগানা) এবং গায়র মাহরাম (গম্য বা বেগানা) সকল আত্মীয়ই শামিল। আত্মীয়তার সম্পর্ক ছিন্ন করা অতি বড় গোনাহ। হাদীসসমূহে সর্বাবস্থায় আত্মীয়তার সম্পর্ক কায়েম রাখার এবং তাদের অধিকার আদায় করার প্রতি বড়ই তাকীদ করা হয়েছে এবং এ কাজের অনেক ফযীলতের কথাও বর্ণিত হয়েছে।তাফসীরে আহসানুল বায়ান
# [('bn', 'সুরা চার, আইআত এক এর বাংলা অনুবাদ পরছি।'),
#  ('bn',
#   'হে মানুষ, তোমরা তোমাদের রবকে ভয় কর, যিনি তোমাদেরকে সৃষ্টি করেছেন এক নফস থেকে।'),
#  ('bn',
#   'আর তা থেকে সৃষ্টি করেছেন তার স্ত্রীকে এবং তাদের থেকে ছড়িয়ে দিয়েছেন বহু পুরুষ ও নারী।'),
#  ('bn', 'আর তোমরা আল্লাহকে ভয় কর, যার মাধ্যমে তোমরা একে অপরের কাছে চেয়ে থাক।'),
#  ('bn', 'আর ভয় কর রক্ত-সম্পর্কিত আত্মীয়ের ব্যাপারে।'),
#  ('bn', 'নিশ্চয় আল্লাহ তোমাদের উপর পর্যবেক্ষক।'),
#  ('bn', '।'),
#  ('bn', 'আইআত টির বাংলা তাফসির পরছি।'),
#  ('bn',
#   '[এক] একটি প্রাণ বলতে মানবকুলের পিতা আদম (আলাইহিস সালাম)-কে বুঝানো হয়েছে।'),
#  ('bn', 'আর।'),
#  ('ar', 'خَلَقَ مِنْهَا زَوْجَهَا'),
#  ('bn', 'এতে।'),
#  ('ar', 'مِنْهَا'),
#  ('bn', 'থেকে উক্ত প্রাণ অর্থাৎ, আদম (আলাইহিস সালাম)-কেই বুঝানো হয়েছে।'),
#  ('bn', 'অর্থাৎ, আদম (আলাইহিস সালাম) থেকেই তাঁর স্ত্রী হাওয়াকে সৃষ্টি করেন।'),
#  ('bn',
#   'আদম (আলাইহিস সালাম) থেকে হাওয়াকে কিভাবে সৃষ্টি করা হয়, এ ব্যাপারে মতভেদ রয়েছে।'),
#  ('bn',
#   'ইবনে আব্বাস (রাদিআল্লাহু আনহু) থেকে বর্ণিত যে, হাওয়া পুরুষ অর্থাৎ, আদম (আলাইহিস সালাম) থেকে সৃষ্টি হয়েছেন।'),
#  ('bn', 'অর্থাৎ, তাঁর পাঁজরের হাড় থেকে।'),
#  ('bn',
#   'অপর একটি হাদীসে বলা হয়েছে যে, নারীদেরকে পাঁজরের হাড় থেকে সৃষ্টি করা হয়েছে।'),
#  ('bn', 'আর পাঁজরের হাড়ের মধ্যে উপরের হাড়টি অধিক বাঁকা।'),
#  ('bn', 'যদি তা সোজা করতে যাও, তাহলে ভেঙ্গে ফেলবে।'),
#  ('bn',
#   'আর যদি তুমি তার দ্বারা উপকৃত হতে চাও, তবে তার মধ্যে বক্রতা অবশিষ্ট থাকা অবস্থাতেই উপকৃত হতে পারবে।'),
#  ('bn',
#   '(বুখারী ৩৩৩এক, মুসলিম একচার৬৮নং) উলামাদের কেউ কেউ এই হাদীসের ভিত্তিতে ইবনে আব্বাস (রাদিআল্লাহু আনহু) থেকে বর্ণিত উক্তিকেই সমর্থন করেছেন।'),
#  ('bn', 'কুরআনের শব্দ।'),
#  ('ar', 'خَلَقَ مِنْهَا'),
#  ('bn', 'থেকেও এই মতের সমর্থন হয়।'),
#  ('bn',
#   'অর্থাৎ, মা হাওয়ার সৃষ্টি সেই একটি প্রাণ থেকেই হয়েছে, যাকে আদম বলা হয়।'),
#  ('bn', '[দুই]।'),
#  ('ar', 'وَالأَرْحَامَ'),
#  ('bn', 'এর সংযোগ।'),
#  ('ar', 'اللَّهَ'),
#  ('bn', 'এর সাথে।'),
#  ('bn', 'অর্থাৎ, আত্মীয়তার সম্পর্ক ছিন্ন করাকেও ভয় কর।'),
#  ('bn', '।'),
#  ('ar', 'أَرْحَامٌ'),
#  ('bn', 'হলো,।'),
#  ('ar', 'رِحِمٌ'),
#  ('bn', 'এর বহুবচন।'),
#  ('bn',
#   'যার অর্থ হল গর্ভাশয়, যেহেতু আত্মীয়তার সম্পর্ক মাতৃগর্ভের ভিত্তিতেই কায়েম হয়।'),
#  ('bn',
#   'এতে মাহরাম (যার সাথে চিরতরের জন্য বিবাহ হারাম, অগম্য বা এগানা) এবং গায়র মাহরাম (গম্য বা বেগানা) সকল আত্মীয়ই শামিল।'),
#  ('bn', 'আত্মীয়তার সম্পর্ক ছিন্ন করা অতি বড় গোনাহ।'),
#  ('bn',
#   'হাদীসসমূহে সর্বাবস্থায় আত্মীয়তার সম্পর্ক কায়েম রাখার এবং তাদের অধিকার আদায় করার প্রতি বড়ই তাকীদ করা হয়েছে এবং এ কাজের অনেক ফযীলতের কথাও বর্ণিত হয়েছে।'),
#  ('bn', 'তাফসীরে আহসানুল বায়ান।')]

# %%
# audio=MLT_TTS(text,resample_audio_to_out_sample_rate=True)
# Audio(audio, rate=MLT_TTS.sample_rate)

# %%
# sf.write(f'/home/apsisdev/mobassir/data/tts/mlt_book_reader/check_mlt.wav', audio/ 32768.0, 22050)
#Audio('/content/check_mlt.wav', autoplay=True)

# %%
len(df.tafsir_bayan_text)
# Out:
# 6236

# %%
def mlt_reader(surah_list,df):
    '''
      surah_list -> list of surah's for what we will be launching MLT TTS
      df         -> dataframe containing all bangla quranic verses and tafsir
    '''
    surah_curr=surah_list[0]
    bn_audio = []
    for i in range(len(df)):
        surah = df.ayat[i].split(",")[0]
        ayat = df.ayat[i].split(",")[1]
        surah_num = int(re.findall(r'\d+', surah)[0])
      
        if(surah_num not in surah_list):
            continue
        else:
            print(f"speaking surah_num -> {surah_num} and -> {ayat}\n\n")
            bn_verse = df.ayat[i].replace("surah","সুরা").replace("ayat","আয়াত")
            bn_verse = bangla.convert_english_digit_to_bangla_digit(bn_verse)
            try:
              bn_qtafsir = bn_verse +" এর বাংলা অনুবাদ পরছি। "+ df.আল_বায়ান[i] + " । " + " আয়াত টির বাংলা তাফসির পরছি। "+df.tafsir_bayan_text[i] 
            except:
              #debug
              print("bn_verse ",bn_verse,"আল_বায়ান ",df.আল_বায়ান[i],"df.tafsir_bayan_text[i]  \n\n",df.tafsir_bayan_text[i] )
            audio=MLT_TTS(bn_qtafsir,resample_audio_to_out_sample_rate=True)
            # if current surah is bein
            if surah_curr==surah_num:    
                bn_audio.append(audio)

                full_surah_audio=np.concatenate(bn_audio,axis=-1)
                sf.write(f'/home/apsisdev/mobassir/data/tts/mlt_book_reader/tafsir_bayan/{surah_num}.wav', full_surah_audio/ 32768.0, 22050)
            else:
                bn_audio=[]
                bn_audio.append(audio)
                surah_curr=surah_num

# %%
df = df.replace(np.nan, 'এটির তাফসির নেই।', regex=True)

# %%
# %%time

# surah_list = range(1,115) #[1]
surah_list = [4]
mlt_reader(surah_list = surah_list,df = df)
# Out:
# speaking surah_num -> 4 and ->  ayat  1
#
#
# skipped
# ['x', 'l', 'q']
# Raw Text Sequence: خلق منها زوجها
# Phoneme Sequence: {x l q m n h aa z uu0 j h aa sil}
# Raw Text Sequence: منها
# Phoneme Sequence: {m n h aa sil}
# skipped
# ['x', 'l', 'q']
# Raw Text Sequence: خلق منها
# Phoneme Sequence: {x l q m n h aa sil}
# Raw Text Sequence: والأرحام
# Phoneme Sequence: {w a l < r H aa m sil}
# skipped
# ['<', 'a', 'l', 'l', 'h']
# Raw Text Sequence: الله
# Phoneme Sequence: {< a l l h sil}
# Raw Text Sequence: أرحام
# Phoneme Sequence: {< a r H aa m sil}
# skipped
# ['r', 'H', 'm']
# Raw Text Sequence: رحم
# Phoneme Sequence: {r H m sil}
# speaking surah_num -> 4 and ->  ayat  2
#
#
# speaking surah_num -> 4 and ->  ayat  3
#
#
# skipped
# ['uu0', 'l', 'n']
# skipped
# ['uu0', 'l', 'uu0']
# skipped
# ['H', 'r', 'S', 't', 'm']
# skipped
# ['k', 'l']
# skipped
# ['k', 'a', 'l', 'm', 'E', 'l', 'q']
# Raw Text Sequence: ولن تستطيعوا أن تعدلوا بين النساء ولو حرصتم فلا تميلوا كل الميل فتذروها كالمعلقة
# Phoneme Sequence: {uu0 l n t s t T ii0 E uu0 < a n t E d l uu0 b ii0 n l n s aa < uu0 l uu0 H r S t m f l aa t m ii0 l uu0 k l l m ii0 l f t * r uu0 h aa k a l m E l q sil}
# speaking surah_num -> 4 and ->  ayat  4
#
#
# speaking surah_num -> 4 and ->  ayat  5
#
#
# speaking surah_num -> 4 and ->  ayat  6
#
#
# speaking surah_num -> 4 and ->  ayat  7
#
#
# speaking surah_num -> 4 and ->  ayat  8
#
#
# speaking surah_num -> 4 and ->  ayat  9
#
#
# speaking surah_num -> 4 and ->  ayat  10
#
#
# speaking surah_num -> 4 and ->  ayat  11
#
#
# speaking surah_num -> 4 and ->  ayat  12
#
#
# Raw Text Sequence: كلالة
# Phoneme Sequence: {k l aa l sil}
# Raw Text Sequence: إكليل
# Phoneme Sequence: {< i0 k l ii0 l sil}
# skipped
# ['k', 'l', 'l']
# Raw Text Sequence: كلل
# Phoneme Sequence: {k l l sil}
# skipped
# ['l', 'l', '*', 'k', 'r']
# skipped
# ['m', '^', 'l']
# skipped
# ['H', 'Z']
# Raw Text Sequence: للذكر مثل حظ الأنثيين
# Phoneme Sequence: {l l * k r m ^ l H Z l < n ^ y ii0 n sil}
# speaking surah_num -> 4 and ->  ayat  13
#
#
# speaking surah_num -> 4 and ->  ayat  14
#
#
# speaking surah_num -> 4 and ->  ayat  15
#
#
# skipped
# ['E', 'd', 'd']
# Raw Text Sequence: عدد
# Phoneme Sequence: {E d d sil}
# Raw Text Sequence: معدود
# Phoneme Sequence: {m E d uu0 d sil}
# skipped
# ['<', 'a', 'r', 'b', 'E']
# Raw Text Sequence: أربعة
# Phoneme Sequence: {< a r b E sil}
# speaking surah_num -> 4 and ->  ayat  16
#
#
# speaking surah_num -> 4 and ->  ayat  17
#
#
# speaking surah_num -> 4 and ->  ayat  18
#
#
# speaking surah_num -> 4 and ->  ayat  19
#
#
# skipped
# ['ii0', 'f', 'r', 'k']
# skipped
# ['m', '<', 'm', 'n']
# skipped
# ['m', '<', 'm', 'n']
# skipped
# ['k', 'r', 'h']
# Raw Text Sequence: لا يفرك مؤمن مؤمنة إن كره منها خلقا رضي منها آخر
# Phoneme Sequence: {l aa ii0 f r k m < m n m < m n < i0 n k r h m n h aa x l q AA r D ii0 m n h aa < aa x r sil}
# speaking surah_num -> 4 and ->  ayat  20
#
#
# Raw Text Sequence: قنطار
# Phoneme Sequence: {q n T AA r sil}
# speaking surah_num -> 4 and ->  ayat  21
#
#
# speaking surah_num -> 4 and ->  ayat  22
#
#
# skipped
# ['uu0', 'l', 'aa']
# skipped
# ['n', 'k', 'H']
# skipped
# ['<', 'aa', 'b', 'aa', '<', 'k', 'm']
# Raw Text Sequence: ولا تنكحوا ما نكح آباؤكم
# Phoneme Sequence: {uu0 l aa t n k H uu0 m aa n k H < aa b aa < k m sil}
# speaking surah_num -> 4 and ->  ayat  23
#
#
# skipped
# ['l', 'l', 'h']
# skipped
# ['<', 'uu0', 'l', 'aa', 'd', 'k', 'm']
# Raw Text Sequence: يوصيكم الله في أولادكم
# Phoneme Sequence: {y UU0 S ii0 k m l l h f ii0 < uu0 l aa d k m sil}
# Raw Text Sequence: ربيبة
# Phoneme Sequence: {r b ii0 b sil}
# skipped
# ['H', 'j', 'uu0', 'r', 'k', 'm']
# Raw Text Sequence: في حجوركم
# Phoneme Sequence: {f ii0 H j uu0 r k m sil}
# Raw Text Sequence: حلائل
# Phoneme Sequence: {H l aa < l sil}
# Raw Text Sequence: حليلة
# Phoneme Sequence: {H l ii0 l sil}
# skipped
# ['H', 'l']
# skipped
# ['ii0', 'H', 'l']
# Raw Text Sequence: حل يحل
# Phoneme Sequence: {H l ii0 H l sil}
# Raw Text Sequence: فعيلة
# Phoneme Sequence: {f E ii0 l sil}
# Raw Text Sequence: فاعلة
# Phoneme Sequence: {f aa E l sil}
# skipped
# ['m', 'n']
# skipped
# ['<', 'A', 'S', 'l', 'aa', 'b', 'k', 'm']
# Raw Text Sequence: من أصلابكم
# Phoneme Sequence: {m n < A S l aa b k m sil}
# speaking surah_num -> 4 and ->  ayat  24
#
#
# Raw Text Sequence: إحصان
# Phoneme Sequence: {< i0 H S AA n sil}
# Raw Text Sequence: محصنات
# Phoneme Sequence: {m H S n aa t sil}
# Raw Text Sequence: استمتاع
# Phoneme Sequence: {s t m t aa E sil}
# speaking surah_num -> 4 and ->  ayat  25
#
#
# speaking surah_num -> 4 and ->  ayat  26
#
#
# speaking surah_num -> 4 and ->  ayat  27
#
#
# Raw Text Sequence: أن تميلوا
# Phoneme Sequence: {< a n t m ii0 l uu0 sil}
# speaking surah_num -> 4 and ->  ayat  28
#
#
# speaking surah_num -> 4 and ->  ayat  29
#
#
# Raw Text Sequence: بالباطل
# Phoneme Sequence: {b aa l b AA T l sil}
# skipped
# ['ii0', 't', 'f', 'r', 'q', 'AA']
# Raw Text Sequence: البيعان بالخيار مالم يتفرقا
# Phoneme Sequence: {< a l b ii0 E aa n b aa l x y aa r m aa l m ii0 t f r q AA sil}
# speaking surah_num -> 4 and ->  ayat  30
#
#
# speaking surah_num -> 4 and ->  ayat  31
#
#
# speaking surah_num -> 4 and ->  ayat  32
#
#
# speaking surah_num -> 4 and ->  ayat  33
#
#
# Raw Text Sequence: موالي
# Phoneme Sequence: {m w aa l ii0 sil}
# Raw Text Sequence: مولى
# Phoneme Sequence: {m uu0 l aa sil}
# skipped
# ['<', 'a', 'y', 'm', 'aa', 'n', 'k', 'm']
# Raw Text Sequence: أيمانكم
# Phoneme Sequence: {< a y m aa n k m sil}
# skipped
# ['n', 'S', 'ii0', 'b', 'h', 'm']
# Raw Text Sequence: نصيبهم
# Phoneme Sequence: {n S ii0 b h m sil}
# skipped
# ['<', 'a', 'y', 'm', 'aa', 'n', 'k', 'm']
# Raw Text Sequence: أيمانكم
# Phoneme Sequence: {< a y m aa n k m sil}
# skipped
# ['uu0', '<', 'uu0', 'l', 'uu0']
# skipped
# ['b', 'E', 'D', 'h', 'm']
# skipped
# ['b', 'b', 'E', 'D']
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: وأولوا الأرحام بعضهم أولى ببعض في كتاب الله
# Phoneme Sequence: {uu0 < uu0 l uu0 l < r H aa m b E D h m < uu0 l aa b b E D f ii0 k t aa b l l h sil}
# skipped
# ['n', 'S', 'ii0', 'b', 'h', 'm']
# Raw Text Sequence: فآتوهم نصيبهم
# Phoneme Sequence: {f < aa t uu0 h m n S ii0 b h m sil}
# skipped
# ['E', 'q', 'd', 't']
# skipped
# ['<', 'a', 'y', 'm', 'aa', 'n', 'k', 'm']
# Raw Text Sequence: والذين عقدت أيمانكم
# Phoneme Sequence: {w a l * ii0 n E q d t < a y m aa n k m sil}
# Raw Text Sequence: الأقربون
# Phoneme Sequence: {< a l < q r b uu0 n sil}
# speaking surah_num -> 4 and ->  ayat  34
#
#
# speaking surah_num -> 4 and ->  ayat  35
#
#
# speaking surah_num -> 4 and ->  ayat  36
#
#
# skipped
# ['l', 'j', 'n', 'b']
# Raw Text Sequence: الجار الجنب
# Phoneme Sequence: {< a l j aa r l j n b sil}
# speaking surah_num -> 4 and ->  ayat  37
#
#
# speaking surah_num -> 4 and ->  ayat  38
#
#
# speaking surah_num -> 4 and ->  ayat  39
#
#
# speaking surah_num -> 4 and ->  ayat  40
#
#
# speaking surah_num -> 4 and ->  ayat  41
#
#
# Raw Text Sequence: شهداء على الناس
# Phoneme Sequence: {$ h d aa < E l aa l n aa s sil}
# skipped
# ['l', 'l', 'h']
# skipped
# ['m', 'n', 'h']
# Raw Text Sequence: أعاذنا الله منه
# Phoneme Sequence: {< a E aa * n aa l l h m n h sil}
# speaking surah_num -> 4 and ->  ayat  42
#
#
# speaking surah_num -> 4 and ->  ayat  43
#
#
# Raw Text Sequence: صعيدا طيبا
# Phoneme Sequence: {S E ii0 d aa T ii0 b aa sil}
# skipped
# ['j', 'E', 'l', 't']
# skipped
# ['l', 'm']
# skipped
# ['n', 'j', 'd']
# Raw Text Sequence: جعلت تربتها لنا طهورا إذا لم نجد الماء
# Phoneme Sequence: {j E l t t r b t h aa l n aa T h uu0 r aa < i0 * aa l m n j d l m aa < sil}
# speaking surah_num -> 4 and ->  ayat  44
#
#
# speaking surah_num -> 4 and ->  ayat  45
#
#
# speaking surah_num -> 4 and ->  ayat  46
#
#
# skipped
# ['m', 's', 'm', 'E']
# Raw Text Sequence: غير مسمع
# Phoneme Sequence: {g ii0 r m s m E sil}
# Raw Text Sequence: راعنا
# Phoneme Sequence: {r aa E n aa sil}
# speaking surah_num -> 4 and ->  ayat  47
#
#
# speaking surah_num -> 4 and ->  ayat  48
#
#
# speaking surah_num -> 4 and ->  ayat  49
#
#
# Raw Text Sequence: فتيل
# Phoneme Sequence: {f t ii0 l sil}
# speaking surah_num -> 4 and ->  ayat  50
#
#
# skipped
# ['<', 'a', 'n', 'f', 's', 'k', 'm']
# skipped
# ['<', 'a', 'E', 'l', 'm']
# skipped
# ['b', 'm', 'n']
# Raw Text Sequence: فلا تزكوا أنفسكم هو أعلم بمن اتقى
# Phoneme Sequence: {f l aa t z k uu0 < a n f s k m h uu0 < a E l m b m n t q AA sil}
# skipped
# ['<', 'a', 'l', 'n', 'j', 'm']
# Raw Text Sequence: النجم
# Phoneme Sequence: {< a l n j m sil}
# speaking surah_num -> 4 and ->  ayat  51
#
#
# speaking surah_num -> 4 and ->  ayat  52
#
#
# speaking surah_num -> 4 and ->  ayat  53
#
#
# Raw Text Sequence: نقير
# Phoneme Sequence: {n q ii0 r sil}
# speaking surah_num -> 4 and ->  ayat  54
#
#
# skipped
# ['m']
# Raw Text Sequence: ام
# Phoneme Sequence: {m sil}
# skipped
# ['b', 'l']
# Raw Text Sequence: بل
# Phoneme Sequence: {b l sil}
# speaking surah_num -> 4 and ->  ayat  55
#
#
# skipped
# ['b', 'h']
# Raw Text Sequence: آمن به
# Phoneme Sequence: {< aa m n b h sil}
# speaking surah_num -> 4 and ->  ayat  56
#
#
# speaking surah_num -> 4 and ->  ayat  57
#
#
# skipped
# ['l', 'l', 'h']
# skipped
# ['m', 'n', 'h', 'm']
# Raw Text Sequence: جعلنا الله منهم
# Phoneme Sequence: {j E l n aa l l h m n h m sil}
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: هدانا الله تعالى
# Phoneme Sequence: {h d aa n aa l l h t E aa l aa sil}
# speaking surah_num -> 4 and ->  ayat  58
#
#
# speaking surah_num -> 4 and ->  ayat  59
#
#
# skipped
# ['uu0', 'l', 'uu0']
# skipped
# ['l', '<', 'm', 'r']
# Raw Text Sequence: اولو الأمر
# Phoneme Sequence: {uu0 l uu0 l < m r sil}
# skipped
# ['l', 'h']
# skipped
# ['l', 'x', 'l', 'q']
# skipped
# ['w', 'a', 'l', '<', 'm', 'r']
# Raw Text Sequence: ألا له الخلق والأمر
# Phoneme Sequence: {< a l aa l h l x l q w a l < m r sil}
# skipped
# ['n']
# skipped
# ['l', 'H', 'k', 'm']
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: ان الحكم إلا لله
# Phoneme Sequence: {n l H k m < i0 l aa l l h sil}
# skipped
# ['m', 'n']
# skipped
# ['II0', 'T', 'E']
# skipped
# ['f', 'q', 'd']
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: من يطع الرسول فقد أطاع الله
# Phoneme Sequence: {m n II0 T E l r s uu0 l f q d < A T AA E l l h sil}
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: أطيعوا الله
# Phoneme Sequence: {< A T ii0 E uu0 l l h sil}
# Raw Text Sequence: أطيعوا الرسول
# Phoneme Sequence: {< A T ii0 E uu0 l r s uu0 l sil}
# skipped
# ['uu0', '<', 'T', 'ii0', 'E', 'uu0']
# skipped
# ['l', '<', 'm', 'r']
# Raw Text Sequence: وأطيعوا أولي الأمر
# Phoneme Sequence: {uu0 < T ii0 E uu0 < uu0 l ii0 l < m r sil}
# Raw Text Sequence: لا طاعة لمخلوق في معصية الخالق
# Phoneme Sequence: {l aa T AA E l m x l UU0 q f ii0 m E S ii0 l x AA l q sil}
# Raw Text Sequence: إنما الطاعة في المعروف
# Phoneme Sequence: {< i0 n m aa l T AA E f ii0 l m E r uu0 f sil}
# speaking surah_num -> 4 and ->  ayat  60
#
#
# speaking surah_num -> 4 and ->  ayat  61
#
#
# skipped
# ['l', 'l', 'h']
# skipped
# ['uu0', 'r', 's', 'uu0', 'l', 'h']
# skipped
# ['l', 'ii0', 'H', 'k', 'm']
# skipped
# ['b', 'ii0', 'n', 'h', 'm']
# skipped
# ['II0', 'q', 'uu0', 'l', 'uu0']
# skipped
# ['uu0', '<', 'T', 'E', 'n', 'aa']
# Raw Text Sequence: إنما كان قول المؤمنين إذا دعوا إلى الله ورسوله ليحكم بينهم أن يقولوا سمعنا وأطعنا
# Phoneme Sequence: {< i0 n m aa k aa n q uu0 l l m < m n ii0 n < i0 * aa d E uu0 < i0 l aa l l h uu0 r s uu0 l h l ii0 H k m b ii0 n h m < a n II0 q uu0 l uu0 s m E n aa uu0 < T E n aa sil}
# skipped
# ['h', 'm']
# Raw Text Sequence: وأولئك هم المفلحون
# Phoneme Sequence: {w a < u0 l aa < i1 k h m l m f l H uu0 n sil}
# speaking surah_num -> 4 and ->  ayat  62
#
#
# speaking surah_num -> 4 and ->  ayat  63
#
#
# speaking surah_num -> 4 and ->  ayat  64
#
#
# speaking surah_num -> 4 and ->  ayat  65
#
#
# speaking surah_num -> 4 and ->  ayat  66
#
#
# speaking surah_num -> 4 and ->  ayat  67
#
#
# speaking surah_num -> 4 and ->  ayat  68
#
#
# speaking surah_num -> 4 and ->  ayat  69
#
#
# speaking surah_num -> 4 and ->  ayat  70
#
#
# speaking surah_num -> 4 and ->  ayat  71
#
#
# skipped
# ['H', '*', 'r', 'k', 'm']
# Raw Text Sequence: حذركم
# Phoneme Sequence: {H * r k m sil}
# speaking surah_num -> 4 and ->  ayat  72
#
#
# speaking surah_num -> 4 and ->  ayat  73
#
#
# speaking surah_num -> 4 and ->  ayat  74
#
#
# skipped
# ['ii0', '$', 'r', 'ii0']
# Raw Text Sequence: شرى يشري
# Phoneme Sequence: {$ r aa ii0 $ r ii0 sil}
# Raw Text Sequence: فليقاتل
# Phoneme Sequence: {f l II0 q AA t l sil}
# skipped
# ['ii0', '$', 'r', 'uu0', 'n']
# Raw Text Sequence: الذين يشرون الحياة
# Phoneme Sequence: {< a l * ii0 n ii0 $ r uu0 n l H y aa sil}
# Raw Text Sequence: الذين
# Phoneme Sequence: {< a l * ii0 n sil}
# Raw Text Sequence: فليقاتل
# Phoneme Sequence: {f l II0 q AA t l sil}
# skipped
# ['<', 'a', 'l', 'm', '<', 'm', 'n']
# Raw Text Sequence: المؤمن النافر
# Phoneme Sequence: {< a l m < m n l n aa f r sil}
# speaking surah_num -> 4 and ->  ayat  75
#
#
# speaking surah_num -> 4 and ->  ayat  76
#
#
# speaking surah_num -> 4 and ->  ayat  77
#
#
# skipped
# ['j', 'l']
# Raw Text Sequence: اجل قريب
# Phoneme Sequence: {j l q r ii0 b sil}
# speaking surah_num -> 4 and ->  ayat  78
#
#
# speaking surah_num -> 4 and ->  ayat  79
#
#
# skipped
# ['k', 'l']
# skipped
# ['m', 'n']
# skipped
# ['E', 'n', 'd']
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: كل من عند الله
# Phoneme Sequence: {k l m n E n d l l h sil}
# skipped
# ['uu0', 'm', 'aa']
# skipped
# ['<', 'A', 'S', 'AA', 'b', 'k', 'm']
# skipped
# ['m', 'n']
# skipped
# ['k', 's', 'b', 't']
# skipped
# ['E', 'n']
# Raw Text Sequence: وما أصابكم من مصيبة فبما كسبت أيديكم ويعفو عن كثير
# Phoneme Sequence: {uu0 m aa < A S AA b k m m n m S ii0 b f b m aa k s b t < a y d ii0 k m w ii0 E f uu0 E n k ^ ii0 r sil}
# speaking surah_num -> 4 and ->  ayat  80
#
#
# speaking surah_num -> 4 and ->  ayat  81
#
#
# speaking surah_num -> 4 and ->  ayat  82
#
#
# speaking surah_num -> 4 and ->  ayat  83
#
#
# skipped
# ['<', 'a', 'l', '<', 'm', 'n']
# Raw Text Sequence: الأمن
# Phoneme Sequence: {< a l < m n sil}
# Raw Text Sequence: الخوف
# Phoneme Sequence: {< a l x uu0 f sil}
# Raw Text Sequence: استنباط
# Phoneme Sequence: {s t n b AA T sil}
# skipped
# ['n', 'b', 'T']
# Raw Text Sequence: نبط
# Phoneme Sequence: {n b T sil}
# skipped
# ['n', 'b', 'T']
# Raw Text Sequence: نبط
# Phoneme Sequence: {n b T sil}
# Raw Text Sequence: استنباط
# Phoneme Sequence: {s t n b AA T sil}
# speaking surah_num -> 4 and ->  ayat  84
#
#
# speaking surah_num -> 4 and ->  ayat  85
#
#
# speaking surah_num -> 4 and ->  ayat  86
#
#
# Raw Text Sequence: تحية
# Phoneme Sequence: {t H ii0 sil}
# skipped
# ['t', 'f', 'E', 'l']
# Raw Text Sequence: تحيية (تفعلة
# Phoneme Sequence: {t H y ii0 t f E l sil}
# Raw Text Sequence: يا
# Phoneme Sequence: {y aa sil}
# Raw Text Sequence: تحية
# Phoneme Sequence: {t H ii0 sil}
# speaking surah_num -> 4 and ->  ayat  87
#
#
# speaking surah_num -> 4 and ->  ayat  88
#
#
# Raw Text Sequence: كسبوا
# Phoneme Sequence: {k s b uu0 sil}
# skipped
# ['<', 'a', 'r', 'k', 's', 'h', 'm']
# Raw Text Sequence: أركسهم
# Phoneme Sequence: {< a r k s h m sil}
# speaking surah_num -> 4 and ->  ayat  89
#
#
# speaking surah_num -> 4 and ->  ayat  90
#
#
# skipped
# ['s', 'l', 'm']
# Raw Text Sequence: سلم
# Phoneme Sequence: {s l m sil}
# Raw Text Sequence: مسالمة
# Phoneme Sequence: {m s aa l m sil}
# speaking surah_num -> 4 and ->  ayat  91
#
#
# skipped
# ['<', 'a', 'l', 'f', 't', 'n']
# Raw Text Sequence: الفتنة
# Phoneme Sequence: {< a l f t n sil}
# Raw Text Sequence: أركسوا فيها
# Phoneme Sequence: {< a r k s uu0 f ii0 h aa sil}
# skipped
# ['ii0', 'l', 'q', 'uu0']
# Raw Text Sequence: يلقوا
# Phoneme Sequence: {ii0 l q uu0 sil}
# skipped
# ['ii0', 'k', 'f', 'uu0']
# Raw Text Sequence: يكفوا
# Phoneme Sequence: {ii0 k f uu0 sil}
# skipped
# ['ii0', 'E', 't', 'z', 'l', 'uu0', 'k', 'm']
# Raw Text Sequence: يعتزلوكم
# Phoneme Sequence: {ii0 E t z l uu0 k m sil}
# skipped
# ['l', 'm']
# Raw Text Sequence: لم
# Phoneme Sequence: {l m sil}
# speaking surah_num -> 4 and ->  ayat  92
#
#
# speaking surah_num -> 4 and ->  ayat  93
#
#
# skipped
# ['m', 'n']
# skipped
# ['uu0', '<', 'aa', 'm', 'n']
# skipped
# ['uu0', 'E', 'm', 'l']
# Raw Text Sequence: إلا من تاب وآمن وعمل عملا صالحا
# Phoneme Sequence: {< i0 l aa m n t aa b uu0 < aa m n uu0 E m l E m l aa S AA l H aa sil}
# Raw Text Sequence: الفرقان
# Phoneme Sequence: {< a l f r q AA n sil}
# speaking surah_num -> 4 and ->  ayat  94
#
#
# speaking surah_num -> 4 and ->  ayat  95
#
#
# skipped
# ['uu0', 'l', 'aa']
# skipped
# ['l', 'D', 'r', 'r']
# Raw Text Sequence: غير اولى الضرر
# Phoneme Sequence: {g ii0 r uu0 l aa l D r r sil}
# skipped
# ['H', 'b', 's', 'h', 'm']
# skipped
# ['l', 'E', '*', 'r']
# Raw Text Sequence: حبسهم العذر
# Phoneme Sequence: {H b s h m l E * r sil}
# speaking surah_num -> 4 and ->  ayat  96
#
#
# speaking surah_num -> 4 and ->  ayat  97
#
#
# speaking surah_num -> 4 and ->  ayat  98
#
#
# speaking surah_num -> 4 and ->  ayat  99
#
#
# speaking surah_num -> 4 and ->  ayat  100
#
#
# Raw Text Sequence: مراغما
# Phoneme Sequence: {m r aa g m aa sil}
# skipped
# ['s', 'E']
# Raw Text Sequence: سعة
# Phoneme Sequence: {s E sil}
# Raw Text Sequence: إنما الأعمال بالنيات
# Phoneme Sequence: {< i0 n m aa l < E m aa l b aa l n y aa t sil}
# skipped
# ['uu0', '<', 'i0', 'n', 'm', 'aa']
# skipped
# ['l', 'k', 'l']
# Raw Text Sequence: وإنما لكل امرىءما نوى
# Phoneme Sequence: {uu0 < i0 n m aa l k l m r aa < m aa n w aa sil}
# speaking surah_num -> 4 and ->  ayat  101
#
#
# skipped
# ['x', 'f', 't', 'm']
# Raw Text Sequence: إن خفتم
# Phoneme Sequence: {< i0 n x f t m sil}
# Raw Text Sequence: لا تأكلوا الربا أضعافا مضاعفة
# Phoneme Sequence: {l aa t < k l uu0 l r b aa < A D E aa f aa m D AA E f sil}
# skipped
# ['uu0', 'l', 'aa']
# skipped
# ['f', 't', 'y', 'aa', 't', 'k', 'm']
# skipped
# ['<', 'a', 'r', 'd', 'n']
# Raw Text Sequence: ولا تكرهوا فتياتكم على البغاء إن أردن تحصنا
# Phoneme Sequence: {uu0 l aa t k r h uu0 f t y aa t k m E l aa l b g AA < < i0 n < a r d n t H S n aa sil}
# skipped
# ['uu0', 'r', 'b', 'aa', '<', 'b', 'k', 'm']
# skipped
# ['H', 'j', 'uu0', 'r', 'k', 'm']
# skipped
# ['m', 'n']
# skipped
# ['n', 's', 'aa', '<', 'k', 'm']
# Raw Text Sequence: وربائبكم اللاتي في حجوركم من نسائكم
# Phoneme Sequence: {uu0 r b aa < b k m l l aa t ii0 f ii0 H j uu0 r k m m n n s aa < k m sil}
# speaking surah_num -> 4 and ->  ayat  102
#
#
# speaking surah_num -> 4 and ->  ayat  103
#
#
# speaking surah_num -> 4 and ->  ayat  104
#
#
# speaking surah_num -> 4 and ->  ayat  105
#
#
# speaking surah_num -> 4 and ->  ayat  106
#
#
# speaking surah_num -> 4 and ->  ayat  107
#
#
# speaking surah_num -> 4 and ->  ayat  108
#
#
# speaking surah_num -> 4 and ->  ayat  109
#
#
# speaking surah_num -> 4 and ->  ayat  110
#
#
# speaking surah_num -> 4 and ->  ayat  111
#
#
# speaking surah_num -> 4 and ->  ayat  112
#
#
# speaking surah_num -> 4 and ->  ayat  113
#
#
# Raw Text Sequence: طائفة
# Phoneme Sequence: {T AA < f sil}
# skipped
# ['m', 'n']
# skipped
# ['k', 'n', 't']
# skipped
# ['uu0', 'l', 'aa']
# Raw Text Sequence: وكذلك أوحينا إليك روحا من أمرنا ما كنت تدري ما الكتاب ولا الأيمان
# Phoneme Sequence: {w a k a * aa l i1 k < uu0 H ii0 n aa < i0 l ii0 k r uu0 H aa m n < a m r n aa m aa k n t t d r ii0 m aa l k t aa b uu0 l aa l < ii0 m aa n sil}
# skipped
# ['uu0', 'm', 'aa']
# skipped
# ['k', 'n', 't']
# skipped
# ['ii0', 'l', 'q', 'AA']
# skipped
# ['r', 'H', 'm']
# skipped
# ['m', 'n']
# skipped
# ['r', 'b', 'k']
# Raw Text Sequence: وما كنت ترجو أن يلقى إليك الكتاب إلا رحمة من ربك
# Phoneme Sequence: {uu0 m aa k n t t r j uu0 < a n ii0 l q AA < i0 l ii0 k l k t aa b < i0 l aa r H m m n r b k sil}
# speaking surah_num -> 4 and ->  ayat  114
#
#
# speaking surah_num -> 4 and ->  ayat  115
#
#
# speaking surah_num -> 4 and ->  ayat  116
#
#
# speaking surah_num -> 4 and ->  ayat  117
#
#
# Raw Text Sequence: إناث
# Phoneme Sequence: {< i0 n aa ^ sil}
# speaking surah_num -> 4 and ->  ayat  118
#
#
# speaking surah_num -> 4 and ->  ayat  119
#
#
# skipped
# ['x', 'l', 'q']
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: تغيير خلق الله
# Phoneme Sequence: {t g y ii0 r x l q l l h sil}
# speaking surah_num -> 4 and ->  ayat  120
#
#
# speaking surah_num -> 4 and ->  ayat  121
#
#
# speaking surah_num -> 4 and ->  ayat  122
#
#
# skipped
# ['UU0', 'q', 'l', 'ii0', 'l']
# skipped
# ['m', 'n']
# Raw Text Sequence: وقليل من عبادي الشكور
# Phoneme Sequence: {UU0 q l ii0 l m n E b aa d ii0 l $ k uu0 r sil}
# speaking surah_num -> 4 and ->  ayat  123
#
#
# speaking surah_num -> 4 and ->  ayat  124
#
#
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: هدانا الله تعالى
# Phoneme Sequence: {h d aa n aa l l h t E aa l aa sil}
# speaking surah_num -> 4 and ->  ayat  125
#
#
# Raw Text Sequence: فعيل
# Phoneme Sequence: {f E ii0 l sil}
# Raw Text Sequence: فاعل
# Phoneme Sequence: {f aa E l sil}
# Raw Text Sequence: مفعول
# Phoneme Sequence: {m f E uu0 l sil}
# speaking surah_num -> 4 and ->  ayat  126
#
#
# speaking surah_num -> 4 and ->  ayat  127
#
#
# skipped
# ['uu0', 'm', 'aa']
# skipped
# ['ii0', 't', 'l', 'aa']
# Raw Text Sequence: وما يتلى عليكم
# Phoneme Sequence: {uu0 m aa ii0 t l aa E l ii0 k m sil}
# skipped
# ['<', 'a', 'l', 'l', 'h']
# skipped
# ['ii0', 'f', 't', 'ii0', 'k', 'm']
# Raw Text Sequence: الله يفتيكم
# Phoneme Sequence: {< a l l h ii0 f t ii0 k m sil}
# Raw Text Sequence: في
# Phoneme Sequence: {f ii0 sil}
# skipped
# ['E', 'n']
# Raw Text Sequence: عن
# Phoneme Sequence: {E n sil}
# skipped
# ['E', 'n']
# Raw Text Sequence: ترغبون عن أن تنكحوهن
# Phoneme Sequence: {t r g b uu0 n E n < a n t n k H uu0 h n sil}
# skipped
# ['r', 'g', 'b']
# Raw Text Sequence: رغب
# Phoneme Sequence: {r g b sil}
# skipped
# ['E', 'n']
# Raw Text Sequence: عن
# Phoneme Sequence: {E n sil}
# skipped
# ['uu0', 'm', 'n']
# skipped
# ['ii0', 'r', 'g', 'b']
# skipped
# ['E', 'n']
# skipped
# ['m', 'l']
# skipped
# ['b', 'r', 'aa', 'h', 'b', 'm']
# Raw Text Sequence: ومن يرغب عن ملة ابراهبم
# Phoneme Sequence: {uu0 m n ii0 r g b E n m l b r aa h b m sil}
# skipped
# ['ii0', 't', 'aa', 'm', 'aa']
# Raw Text Sequence: يتامى النساء
# Phoneme Sequence: {ii0 t aa m aa l n s aa < sil}
# skipped
# ['uu0', 'm', 'aa']
# skipped
# ['ii0', 't', 'l', 'aa']
# skipped
# ['ii0', 't', 'aa', 'm', 'aa']
# skipped
# ['uu0', 'f', 'ii0']
# skipped
# ['m', 'n']
# Raw Text Sequence: وما يتلى عليكم في يتامى النساء وفي المستضعفين من الولدان
# Phoneme Sequence: {uu0 m aa ii0 t l aa E l ii0 k m f ii0 ii0 t aa m aa l n s aa < uu0 f ii0 l m s t D E f ii0 n m n l uu0 l d aa n sil}
# skipped
# ['l', 'l', 'h']
# skipped
# ['uu0', 'l', 'aa', 'd', 'k', 'm']
# Raw Text Sequence: يوصيكم الله في اولادكم
# Phoneme Sequence: {y UU0 S ii0 k m l l h f ii0 uu0 l aa d k m sil}
# skipped
# ['ii0', 't', 'aa', 'm', 'aa']
# Raw Text Sequence: يتامى النساء
# Phoneme Sequence: {ii0 t aa m aa l n s aa < sil}
# speaking surah_num -> 4 and ->  ayat  128
#
#
# skipped
# ['$', 'H']
# Raw Text Sequence: شح
# Phoneme Sequence: {$ H sil}
# speaking surah_num -> 4 and ->  ayat  129
#
#
# speaking surah_num -> 4 and ->  ayat  130
#
#
# couldn't numerize  সুরা ৪, আয়াত  ১৩০ এর বাংলা অনুবাদ পরছি। আর যদি তারা উভয়ে বিচ্ছিন্ন হয়ে যায় তবে আল্লাহ প্রত্যেককে নিজ প্রাচুর্য দ্বারা অভাবমুক্ত করবেন। আর আল্লাহ প্রাচুর্যময়, প্রজ্ঞাবান।  ।  আয়াত টির বাংলা তাফসির পরছি। [১] এখানে তৃতীয় অবস্থার কথা বলা হচ্ছে যে, প্রচেষ্টা সত্ত্বেও যদি বনিবনাও না হয়, তাহলে তারা তালাকের মাধ্যমে পরস্পর থেকে পৃথক হয়ে যাবে। হতে পারে তালাকের পর পুরুষ তার চাহিদার গুণের নারী এবং মহিলা তার চাহিদার গুণের পুরুষ পেয়ে যাবে। ইসলামে তালাককে চরম ঘৃণা করা হয়েছে। একটি হাদীসে এসেছে যে, (أَبْغَضُ الحَلاَلِ إِلَى اللهِ الطَّلاَقُ) অর্থাৎ, তালাক আল্লাহর নিকট সর্বাধিক ঘৃণিত হালাল বস্তু। (আবূ দাঊদ) তা সত্ত্বেও আল্লাহ তাতে অনুমতি দিয়েছেন। কারণ, কোন কোন সময় পরিস্থিতি এমন পর্যায়ে গিয়ে পৌঁছে যে, তালাক ব্যতীত অন্য কোন উপায় থাকে না এবং তাদের উভয় পক্ষের মঙ্গল একে অপর থেকে পৃথক হওয়ার মধ্যেই থাকে। উল্লিখিত হাদীস সনদের দিক দিয়ে দুর্বল হলেও কুরআন ও হাদীসের উক্তির দ্বারা এ কথা পরিষ্কার হয় যে, এ (তালাকের) অধিকার তখনই কার্যকরী করা উচিত, যখন কোনভাবেই বনিবনাও সম্ভব হবে না।দ্রষ্টব্যঃ উল্লিখিত হাদীস (أَبْغَضُ الحَلاَل...)কে আল্লামা আলবানী দুর্বল বলেছেন। (ইরওয়াউল গালীলঃ ২০৪০নং) তবে শরয়ী কোন কারণ ছাড়া তালাক দেওয়া যে অপছন্দনীয় তাতে কোন সন্দেহ নেই।তাফসীরে আহসানুল বায়ান
# skipped
# ['<', 'a', 'b', 'g', 'D']
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: أبغض الحلال إلى الله الطلاق
# Phoneme Sequence: {< a b g D l H l aa l < i0 l aa l l h l T l AA q sil}
# skipped
# ['<', 'a', 'b', 'g', 'D']
# Raw Text Sequence: أبغض الحلال
# Phoneme Sequence: {< a b g D l H l aa l sil}
# speaking surah_num -> 4 and ->  ayat  131
#
#
# speaking surah_num -> 4 and ->  ayat  132
#
#
# speaking surah_num -> 4 and ->  ayat  133
#
#
# skipped
# ['uu0', '<', 'i1', 'n']
# skipped
# ['ii0', 's', 't', 'b', 'd', 'l']
# skipped
# ['g', 'ii0', 'r', 'k', 'm']
# skipped
# ['^', 'm']
# skipped
# ['ii0', 'k', 'uu0', 'n', 'uu0']
# skipped
# ['<', 'a', 'm', '^', 'aa', 'l', 'k', 'm']
# Raw Text Sequence: وإن تتولوا يستبدل قوما غيركم ثم لا يكونوا أمثالكم
# Phoneme Sequence: {uu0 < i1 n t t uu0 l uu0 ii0 s t b d l q uu0 m aa g ii0 r k m ^ m l aa ii0 k uu0 n uu0 < a m ^ aa l k m sil}
# skipped
# ['m', 'H', 'm', 'd']
# Raw Text Sequence: محمد
# Phoneme Sequence: {m H m d sil}
# speaking surah_num -> 4 and ->  ayat  134
#
#
# speaking surah_num -> 4 and ->  ayat  135
#
#
# skipped
# ['uu0', 'l', 'aa']
# skipped
# ['ii0', 'j', 'r', 'm', 'n', 'k', 'm']
# Raw Text Sequence: ولا يجرمنكم شنآن قوم على ألا تعدلوا اعدلوا
# Phoneme Sequence: {uu0 l aa ii0 j r m n k m $ n < aa n q uu0 m E l aa < a l aa t E d l uu0 E d l uu0 sil}
# skipped
# ['t', 'l', 'uu0', 'uu0']
# Raw Text Sequence: تلووا
# Phoneme Sequence: {t l uu0 uu0 sil}
# Raw Text Sequence: لي
# Phoneme Sequence: {l ii0 sil}
# speaking surah_num -> 4 and ->  ayat  136
#
#
# Raw Text Sequence: اهدنا الصراط المستقيم
# Phoneme Sequence: {h d n aa l S r AA T l m s t q ii0 m sil}
# speaking surah_num -> 4 and ->  ayat  137
#
#
# speaking surah_num -> 4 and ->  ayat  138
#
#
# speaking surah_num -> 4 and ->  ayat  139
#
#
# skipped
# ['m', 'n']
# skipped
# ['ii0', 'r', 'ii0', 'd']
# skipped
# ['l', 'E', 'z']
# skipped
# ['f', 'l', 'l', 'h']
# skipped
# ['l', 'E', 'z']
# Raw Text Sequence: من كان يريد العزة فلله العزة جميعا
# Phoneme Sequence: {m n k aa n ii0 r ii0 d l E z f l l h l E z j m ii0 E aa sil}
# skipped
# ['uu0', 'l', 'l', 'h']
# skipped
# ['l', 'E', 'z']
# skipped
# ['uu0', 'l', 'r', 's', 'uu0', 'l', 'h']
# skipped
# ['uu0', 'l', 'l', 'm', '<', 'm', 'n', 'ii0', 'n']
# skipped
# ['ii0', 'E', 'l', 'm', 'uu0', 'n']
# Raw Text Sequence: ولله العزة ولرسوله وللمؤمنين ولكن المنافقين لا يعلمون
# Phoneme Sequence: {uu0 l l h l E z uu0 l r s uu0 l h uu0 l l m < m n ii0 n w a l aa k i1 n l m n aa f q ii0 n l aa ii0 E l m uu0 n sil}
# speaking surah_num -> 4 and ->  ayat  140
#
#
# skipped
# ['n', 'k', 'm']
# skipped
# ['m', '^', 'l', 'h', 'm']
# Raw Text Sequence: انكم اذا مثلهم
# Phoneme Sequence: {n k m * aa m ^ l h m sil}
# speaking surah_num -> 4 and ->  ayat  141
#
#
# skipped
# ['uu0', 'm', 'aa']
# skipped
# ['<', 'A', 'S', 'AA', 'b', 'k', 'm']
# skipped
# ['m', 'n']
# skipped
# ['k', 's', 'b', 't']
# Raw Text Sequence: وما أصابكم من مصيبة فبما كسبت أيديكم
# Phoneme Sequence: {uu0 m aa < A S AA b k m m n m S ii0 b f b m aa k s b t < a y d ii0 k m sil}
# speaking surah_num -> 4 and ->  ayat  142
#
#
# skipped
# ['<', 'a', '^', 'q', 'l']
# skipped
# ['UU0', 'S', 'l', 'aa']
# skipped
# ['l', 'f', 'j', 'r']
# Raw Text Sequence: إن أثقل صلاة على المنافقين صلاة العشاء وصلاة الفجر
# Phoneme Sequence: {< i0 n < a ^ q l S l aa E l aa l m n aa f q ii0 n S l aa l E $ aa < UU0 S l aa l f j r sil}
# skipped
# ['II0', 'S', 'l', 'uu0', 'n']
# Raw Text Sequence: لا يصلون إلا صلاة قليلة
# Phoneme Sequence: {l aa II0 S l uu0 n < i0 l aa S l aa q l ii0 l sil}
# skipped
# ['uu0', '<', 'i0', 'n', 'h', 'aa']
# Raw Text Sequence: وإنها لكبيرة إلا على الخاشعين
# Phoneme Sequence: {uu0 < i0 n h aa l k b ii0 r < i0 l aa E l aa l x AA $ E ii0 n sil}
# speaking surah_num -> 4 and ->  ayat  143
#
#
# speaking surah_num -> 4 and ->  ayat  144
#
#
# speaking surah_num -> 4 and ->  ayat  145
#
#
# Raw Text Sequence: هاوية
# Phoneme Sequence: {h aa w ii0 sil}
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: أعاذنا الله منها
# Phoneme Sequence: {< a E aa * n aa l l h m n h aa sil}
# speaking surah_num -> 4 and ->  ayat  146
#
#
# speaking surah_num -> 4 and ->  ayat  147
#
#
# speaking surah_num -> 4 and ->  ayat  148
#
#
# speaking surah_num -> 4 and ->  ayat  149
#
#
# skipped
# ['uu0', 'j', 'z', 'aa', '<']
# skipped
# ['f', 'm', 'n']
# skipped
# ['uu0', '<', 'S', 'l', 'H']
# skipped
# ['f', '<', 'j', 'r', 'h']
# skipped
# ['l', 'l', 'h']
# skipped
# ['ii0', 'H', 'b']
# Raw Text Sequence: وجزاء سيئة سيئة مثلها فمن عفا وأصلح فأجره على الله إنه لا يحب الظالمين
# Phoneme Sequence: {uu0 j z aa < s ii0 < s ii0 < m ^ l h aa f m n E f aa uu0 < S l H f < j r h E l aa l l h < i0 n h l aa ii0 H b l Z AA l m ii0 n sil}
# speaking surah_num -> 4 and ->  ayat  150
#
#
# speaking surah_num -> 4 and ->  ayat  151
#
#
# speaking surah_num -> 4 and ->  ayat  152
#
#
# speaking surah_num -> 4 and ->  ayat  153
#
#
# speaking surah_num -> 4 and ->  ayat  154
#
#
# speaking surah_num -> 4 and ->  ayat  155
#
#
# skipped
# ['f', 'b', 'n', 'q', 'D', 'h', 'm']
# skipped
# ['m', 'ii0', '^', 'AA', 'q', 'h', 'm']
# Raw Text Sequence: فبنقضهم ميثاقهم لعناهم
# Phoneme Sequence: {f b n q D h m m ii0 ^ AA q h m l E n aa h m sil}
# speaking surah_num -> 4 and ->  ayat  156
#
#
# skipped
# ['n', 'E', 'uu0', '*', 'b', 'aa', 'l', 'l', 'h']
# Raw Text Sequence: نعوذبالله
# Phoneme Sequence: {n E uu0 * b aa l l h sil}
# speaking surah_num -> 4 and ->  ayat  157
#
#
# speaking surah_num -> 4 and ->  ayat  158
#
#
# speaking surah_num -> 4 and ->  ayat  159
#
#
# skipped
# ['q', 'b', 'l']
# Raw Text Sequence: قبل موته
# Phoneme Sequence: {q b l m uu0 t h sil}
# skipped
# ['h']
# Raw Text Sequence: ه
# Phoneme Sequence: {h sil}
# Raw Text Sequence: موته
# Phoneme Sequence: {m uu0 t h sil}
# skipped
# ['uu0', '<', 'i1', 'n']
# skipped
# ['m', 'n']
# skipped
# ['l', 'ii0', '<', 'm', 'n', 'n']
# skipped
# ['b', 'h']
# skipped
# ['q', 'b', 'l']
# Raw Text Sequence: وإن من أهل الكتاب إلا ليؤمنن به قبل موته
# Phoneme Sequence: {uu0 < i1 n m n < a h l l k t aa b < i0 l aa l ii0 < m n n b h q b l m uu0 t h sil}
# skipped
# ['uu0', 'k', 'n', 't']
# skipped
# ['d', 'm', 't']
# Raw Text Sequence: وكنت عليهم شهيدا ما دمت فيهم
# Phoneme Sequence: {uu0 k n t E l ii0 h m $ h ii0 d aa m aa d m t f ii0 h m sil}
# speaking surah_num -> 4 and ->  ayat  160
#
#
# speaking surah_num -> 4 and ->  ayat  161
#
#
# speaking surah_num -> 4 and ->  ayat  162
#
#
# speaking surah_num -> 4 and ->  ayat  163
#
#
# speaking surah_num -> 4 and ->  ayat  164
#
#
# speaking surah_num -> 4 and ->  ayat  165
#
#
# skipped
# ['uu0', 'l', 'uu0']
# skipped
# ['m', 'n']
# skipped
# ['q', 'b', 'l', 'h']
# skipped
# ['<', 'a', 'r', 's', 'l', 't']
# skipped
# ['f', 'n', 't', 'b', 'E']
# skipped
# ['m', 'n']
# skipped
# ['q', 'b', 'l']
# skipped
# ['n', '*', 'l']
# skipped
# ['uu0', 'n', 'x', 'z', 'aa']
# Raw Text Sequence: ولو أنا أهلكناهم بعذاب من قبله لقالوا ربنا لولا أرسلت إلينا رسولا فنتبع آياتك من قبل أن نذل ونخزى
# Phoneme Sequence: {uu0 l uu0 < a n aa < a h l k n aa h m b E * aa b m n q b l h l q AA l uu0 r b n aa l uu0 l aa < a r s l t < i0 l ii0 n aa r s uu0 l aa f n t b E < aa y aa t k m n q b l < a n n * l uu0 n x z aa sil}
# speaking surah_num -> 4 and ->  ayat  166
#
#
# speaking surah_num -> 4 and ->  ayat  167
#
#
# speaking surah_num -> 4 and ->  ayat  168
#
#
# speaking surah_num -> 4 and ->  ayat  169
#
#
# speaking surah_num -> 4 and ->  ayat  170
#
#
# skipped
# ['<', 'a', 'n', 't', 'm']
# skipped
# ['uu0', 'm', 'n']
# skipped
# ['l', '<', 'r', 'D']
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: إن تكفروا أنتم ومن في الأرض جميعا فإن الله لغني حميد
# Phoneme Sequence: {< i0 n t k f r uu0 < a n t m uu0 m n f ii0 l < r D j m ii0 E aa f < i1 n l l h l g n ii0 H m ii0 d sil}
# speaking surah_num -> 4 and ->  ayat  171
#
#
# Raw Text Sequence: غلو
# Phoneme Sequence: {g l uu0 sil}
# skipped
# ['<', 'a', 'H', 'b', 'aa', 'r', 'h', 'm']
# skipped
# ['uu0', 'r', 'h', 'b', 'aa', 'n', 'h', 'm']
# skipped
# ['m', 'n']
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: اتخذوا أحبارهم ورهبانهم أربابا من دون الله
# Phoneme Sequence: {t x * uu0 < a H b aa r h m uu0 r h b aa n h m < a r b aa b aa m n d uu0 n l l h sil}
# skipped
# ['l', 'l', 'h']
# skipped
# ['uu0', '<', 'i0', 'n', 'aa']
# Raw Text Sequence: فإنا لله وإنا إليه راجعون
# Phoneme Sequence: {f < i0 n aa l l h uu0 < i0 n aa < i0 l ii0 h r aa j E uu0 n sil}
# skipped
# ['k', 'l', 'm']
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: كلمة الله
# Phoneme Sequence: {k l m l l h sil}
# skipped
# ['k', 'n']
# Raw Text Sequence: كن
# Phoneme Sequence: {k n sil}
# skipped
# ['l', 'l', 'h']
# Raw Text Sequence: روح الله
# Phoneme Sequence: {w a l l h sil}
# speaking surah_num -> 4 and ->  ayat  172
#
#
# speaking surah_num -> 4 and ->  ayat  173
#
#
# skipped
# ['ii0', 's', 't', 'k', 'b', 'r', 'uu0', 'n']
# skipped
# ['E', 'n']
# skipped
# ['j', 'h', 'n', 'm']
# Raw Text Sequence: إن الذين يستكبرون عن عبادتي سيدخلون جهنم داخرين
# Phoneme Sequence: {< i0 n l * ii0 n ii0 s t k b r uu0 n E n E b aa d t ii0 s ii0 d x l uu0 n j h n m d aa x r ii0 n sil}
# speaking surah_num -> 4 and ->  ayat  174
#
#
# Raw Text Sequence: برهان
# Phoneme Sequence: {b r h aa n sil}
# speaking surah_num -> 4 and ->  ayat  175
#
#
# speaking surah_num -> 4 and ->  ayat  176
#
#
# Raw Text Sequence: كلالة
# Phoneme Sequence: {k l aa l sil}
# CPU times: user 49min 59s, sys: 4min 35s, total: 54min 34s
# Wall time: 19min 8s

# %%
# !pwd
# Out:
# /home/apsisdev/mobassir/data/tts/mlt_book_reader

# %%
# from IPython.display import Audio 
# Audio('/content/1.wav', autoplay=True)
